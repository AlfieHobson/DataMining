# %%
import time
import math
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import scikitplot as skplt
import sklearn 

from sklearn import tree
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

from pylab import rcParams

from sklearn.neural_network import MLPClassifier

# %matplotlib inline

#pip install matplotlib==3.1.0 --upgrade --force to fix confusion matrix issue

#https://towardsdatascience.com/knn-using-scikit-learn-c6bed765be75
#https://towardsdatascience.com/building-a-k-nearest-neighbors-k-nn-model-with-scikit-learn-51209555453a

#clf = tree.DecisionTreeClassifier()
#clf = clf.fit(data_copy, data_copy.target)
#tree.plot_tree(clf)

# %%
data = pd.read_csv('600092_data.csv')

# %% [markdown]
# # 1. Understanding the Data

# %%
data_copy = data
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 11 columns):
# Random          1520 non-null float64
# Id              1520 non-null int64
# Indication      1517 non-null object
# Diabetes        1518 non-null object
# IHD             1520 non-null object
# Hypertension    1517 non-null object
# Arrhythmia      1520 non-null object
# History         1518 non-null object
# IPSI            1516 non-null float64
# Contra          1520 non-null object
# label           1517 non-null object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 83.2+ KB

# %%
data_copy.head()
# Out:
#      Random      Id Indication Diabetes  IHD Hypertension Arrhythmia History  \
# 0  0.602437  218242        A-F       no   no          yes         no      no
# 1  0.602437  159284        TIA       no   no           no         no      no
# 2  0.602437  106066        A-F       no  yes          yes         no      no
# 3  0.128157  229592        TIA       no   no          yes         no      no
# 4  0.676862  245829        CVA       no   no           no         no      no
#
#    IPSI Contra   label
# 0  78.0    20   NoRisk
# 1  70.0    60   NoRisk
# 2  95.0     40    Risk
# 3  90.0     85    Risk
# 4  70.0    20   NoRisk

# %% [markdown]
# # 2. Cleaning the Data
# ### 2.1 Removing Null Values

# %%
data_copy.isna().sum()
# Out:
# Random          0
# Id              0
# Indication      3
# Diabetes        2
# IHD             0
# Hypertension    3
# Arrhythmia      0
# History         2
# IPSI            4
# Contra          0
# label           3
# dtype: int64

# %%
data_copy.dropna(inplace=True)

# %%
data_copy.isna().sum()
# Out:
# Random          0
# Id              0
# Indication      0
# Diabetes        0
# IHD             0
# Hypertension    0
# Arrhythmia      0
# History         0
# IPSI            0
# Contra          0
# label           0
# dtype: int64

# %% [markdown]
# ### 2.2 Removing column Random

# %%
data_copy = data_copy.drop(columns=['Random'])

# %% [markdown]
# ### 2.3 Inspecting column ID
# #### This column should contain uniques. Checking for duplicates

# %%
duplicateRowsDF = data_copy[data_copy.duplicated(['Id'])]
duplicateRowsDF

if duplicateRowsDF.empty :
    print ("No Duplicates")
else:
    duplicateRowsDF
# Out:
# No Duplicates

# %% [markdown]
# #### Removing column Id
# No duplicates are present. Therefore it is assumed all data is unique. No further use for ID column and therefore dropping.

# %%
data_copy = data_copy.drop(columns=['Id'])

# %% [markdown]
# ### 2.4 Inspecting column Indication

# %%
data_copy['Indication'].value_counts(dropna=False)
# Out:
# A-F    489
# CVA    408
# TIA    388
# ASx    186
# Asx     32
# Name: Indication, dtype: int64

# %% [markdown]
# #### Setting all values to upper case
# As seen above, we are reading 5 different values for Indication when there should only be 4.
# This is due to two values being the same but having different capitialisation.
# Setting all values in our data to uppercase to solve this and avoid any further errors.

# %%
# Change all my string data to Uppercase to avoid any
data_copy['Indication'] = data_copy['Indication'].str.upper()
data_copy['Diabetes'] = data_copy['Diabetes'].str.upper() 
data_copy['IHD'] = data_copy['IHD'].str.upper() 
data_copy['Hypertension'] = data_copy['Hypertension'].str.upper() 
data_copy['Arrhythmia'] = data_copy['Arrhythmia'].str.upper() 
data_copy['History'] = data_copy['History'].str.upper() 
data_copy['label'] = data_copy['label'].str.upper() 

data_copy['Indication'].value_counts(dropna=False)
# Out:
# A-F    489
# CVA    408
# TIA    388
# ASX    218
# Name: Indication, dtype: int64

# %%
# Displays count Indication graph

#sb.countplot(data = data_copy, x= "Indication")
#y = plt.ylabel("Amount of People")
#sb.catplot('label', col="Indication", data = data_copy,kind='count' , height = 2.5)

# %% [markdown]
# #### One Hot Encoding - Indication
# Using One Hot Encoding to split Indication into 4 boolean columns to prevent the data being misinterpreted later on in other algorithms.
# https://pbpython.com/categorical-encoding.html

# %%
data_copy = pd.get_dummies(data_copy, columns=["Indication"])
data_copy.head()
# Out:
#   Diabetes  IHD Hypertension Arrhythmia History  IPSI Contra   label  \
# 0       NO   NO          YES         NO      NO  78.0    20   NORISK
# 1       NO   NO           NO         NO      NO  70.0    60   NORISK
# 2       NO  YES          YES         NO      NO  95.0     40    RISK
# 3       NO   NO          YES         NO      NO  90.0     85    RISK
# 4       NO   NO           NO         NO      NO  70.0    20   NORISK
#
#    Indication_A-F  Indication_ASX  Indication_CVA  Indication_TIA
# 0               1               0               0               0
# 1               0               0               0               1
# 2               1               0               0               0
# 3               0               0               0               1
# 4               0               0               1               0

# %% [markdown]
# ### 2.5 Inspecting each binary column.

# %%
data_copy['Diabetes'].value_counts(dropna=False)
# Out:
# NO     1428
# YES      75
# Name: Diabetes, dtype: int64

# %%
data_copy['IHD'].value_counts(dropna=False)
# Out:
# NO     791
# YES    712
# Name: IHD, dtype: int64

# %%
data_copy['Hypertension'].value_counts(dropna=False)
# Out:
# NO     777
# YES    726
# Name: Hypertension, dtype: int64

# %%
data_copy['Arrhythmia'].value_counts(dropna=False)
# Out:
# NO     1179
# YES     324
# Name: Arrhythmia, dtype: int64

# %%
data_copy['History'].value_counts(dropna=False)
# Out:
# NO     1481
# YES      22
# Name: History, dtype: int64

# %% [markdown]
# #### Changing each binary column to display True for YES and False for NO.
# Setting these values to true and false will make them readable to algorithms and models later on

# %%
# Creating a map to change YES and NO to True and False respectively
yesToTrue = {'YES': True,'NO': False}

# Creating new columns in our data, Displaying True or False instead
data_copy = data_copy.assign(Diabetes_bool = data_copy['Diabetes'].map(yesToTrue),
                      IHD_bool = data_copy['IHD'].map(yesToTrue),
                      Hypertension_bool = data_copy['Hypertension'].map(yesToTrue),
                      Arrhythmia_bool = data_copy['Arrhythmia'].map(yesToTrue),
                      History_bool = data_copy['History'].map(yesToTrue))

# Now dropping the old columns which displayed YES or NO
data_copy = data_copy.drop(columns=['Diabetes','IHD','Hypertension','Arrhythmia','History'])

data_copy.head()
# Out:
#    IPSI Contra   label  Indication_A-F  Indication_ASX  Indication_CVA  \
# 0  78.0    20   NORISK               1               0               0
# 1  70.0    60   NORISK               0               0               0
# 2  95.0     40    RISK               1               0               0
# 3  90.0     85    RISK               0               0               0
# 4  70.0    20   NORISK               0               0               1
#
#    Indication_TIA  Diabetes_bool  IHD_bool  Hypertension_bool  \
# 0               0          False     False               True
# 1               1          False     False              False
# 2               0          False      True               True
# 3               1          False     False               True
# 4               0          False     False              False
#
#    Arrhythmia_bool  History_bool
# 0            False         False
# 1            False         False
# 2            False         False
# 3            False         False
# 4            False         False

# %% [markdown]
# ### 2.6 Inspecting column Contra

# %%
data_copy['Contra'].value_counts(dropna=False)
# Out:
# 100     238
# 20      191
# 30      150
# 50      131
# 40      101
# 60       93
# 50       51
# 10       49
# 100      39
# 90       34
# 70       34
# 95       32
# 75       31
# 25       30
# 75       29
# 80       29
# 80       24
# 85       24
# 35       22
# 15       18
# 70       18
# 55       14
# 65       13
# 30       12
# 51       11
# 85       11
# 90       10
# 53        9
# 55        9
# 73        7
# 40        7
# 60        6
# 45        6
# 35        5
# 16        4
# 65        4
# 62        3
# 79        2
#           1
# 10        1
# Name: Contra, dtype: int64

# %% [markdown]
# #### Compare column Contra to IPSI
# An empty value is present in Contra.
# Will compare to IPSI to see if any coorelation is present.

# %%
colour = data_copy.label.map({'RISK':'b','NORISK':'r', 'UNKNOWN':'g', 'NAN':'y' })
ax1 = plt.scatter(data_copy['Contra'], data_copy['IPSI'],c= colour)
ax1.axes.set_ylabel('IPSI')
ax1.axes.set_xlabel('Contra')
# Out:
# Text(0.5, 0, 'Contra')

# %% [markdown]
# #### Turning empty value in Contra to NaN
# No correlation was found between Contra and IPSI alone. Therefore changing the value to NaN and will drop later.

# %%
data_copy=data_copy.replace(r'^\s*$', np.nan, regex=True)#
#data_copy.dropna(inplace=True)
#data_copy['Contra'].value_counts(dropna=False)

# %% [markdown]
# ### 2.7 Inspect column label

# %%
data_copy['label'].value_counts(dropna=False)
# Out:
# NORISK     1001
# RISK        500
# UNKNOWN       2
# Name: label, dtype: int64

# %% [markdown]
# #### Removing records contain UNKNOWN
# Column lable contains two UNKNOWN values.
# Changing these to NaN and dropping

# %%
data_copy['label'] = data_copy['label'].replace("UNKNOWN", np.nan)
data_copy.dropna(inplace=True)

# %%
# Creating a map to change YES and NO to True and False respectively
riskToTrue = {'RISK': 1,'NORISK': 0}

data_copy = data_copy.assign(label_bool = data_copy['label'].map(riskToTrue))
data_copy = data_copy.drop(columns=['label'])
data_copy.head()
# Out:
#    IPSI Contra  Indication_A-F  Indication_ASX  Indication_CVA  \
# 0  78.0    20                1               0               0
# 1  70.0    60                0               0               0
# 2  95.0     40               1               0               0
# 3  90.0     85               0               0               0
# 4  70.0    20                0               0               1
#
#    Indication_TIA  Diabetes_bool  IHD_bool  Hypertension_bool  \
# 0               0          False     False               True
# 1               1          False     False              False
# 2               0          False      True               True
# 3               1          False     False               True
# 4               0          False     False              False
#
#    Arrhythmia_bool  History_bool  label_bool
# 0            False         False           0
# 1            False         False           0
# 2            False         False           1
# 3            False         False           1
# 4            False         False           0

# %% [markdown]
# # 3. Data Models
# Will be creating multiple models to analyse the data.
# These models will be using a 70%-30% split of training and test data respectively.
#
# ## 3.1 Defining Test and Training Data
# ### Define X & Y.
# X being our cleaned and filtered data without the label column.
# Y being our label values.

# %%
# Define our x and y values for our training model
# X contains all columns except label
X = data_copy.drop(columns=['label_bool'])

# Y contains label values.
Y = data_copy['label_bool'].values

# %% [markdown]
# ### Create train test split
# Once we have our X and Y, we can split our data into 30% test data and 70% training data

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, shuffle=True)

# %% [markdown]
# ## 3.2 Nearest Neighbour Model (KNN)
# https://towardsdatascience.com/building-a-k-nearest-neighbors-k-nn-model-with-scikit-learn-51209555453a
# https://towardsdatascience.com/knn-using-scikit-learn-c6bed765be75
# https://www.quora.com/How-can-I-choose-the-best-K-in-KNN-K-nearest-neighbour-classification
# KNN model requires a value K. K determines how many neighbours are used to decide a given value.
#
# To find the best value for K, we will create multiple KNN models with different K values and inspect each of their accuracies.

# %% [markdown]
# ### 3.2.1 Finding a value for K - Using Predictor

# %%
k_range = range(1,50)
knn_scores = {}
knn_scores_list = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k, metric ='euclidean')
    knn.fit(xTrain,yTrain)
    yPred = knn.predict(xTest)
    knn_scores[k] = metrics.accuracy_score(yTest,yPred)
    knn_scores_list.append(metrics.accuracy_score(yTest,yPred))

# %%
plt.plot(k_range,knn_scores_list)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
print(knn_scores_list)
## 0.98, 0.9822, 0.991, 0.984
# Out:
# [0.9777777777777777, 0.9711111111111111, 0.9511111111111111, 0.9466666666666667, 0.9422222222222222, 0.9222222222222223, 0.92, 0.9155555555555556, 0.9111111111111111, 0.9066666666666666, 0.9155555555555556, 0.9044444444444445, 0.9066666666666666, 0.9133333333333333, 0.9022222222222223, 0.8933333333333333, 0.8844444444444445, 0.8822222222222222, 0.88, 0.8777777777777778, 0.8733333333333333, 0.88, 0.8688888888888889, 0.8688888888888889, 0.8666666666666667, 0.8511111111111112, 0.8377777777777777, 0.8444444444444444, 0.8644444444444445, 0.8666666666666667, 0.8555555555555555, 0.86, 0.8622222222222222, 0.8644444444444445, 0.8644444444444445, 0.8422222222222222, 0.8377777777777777, 0.84, 0.8377777777777777, 0.8377777777777777, 0.8244444444444444, 0.8288888888888889, 0.8244444444444444, 0.8288888888888889, 0.8288888888888889, 0.8288888888888889, 0.8288888888888889, 0.8288888888888889, 0.8311111111111111]

# %% [markdown]
# ### 3.2.2 Finding a value for K - Using K-Fold Cross Validation

# %%
cv_scores = {}
cv_scores_list = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k, metric ='euclidean')
    cv_scores[k] = np.mean(cross_val_score(knn, X, Y, cv=10))
    cv_scores_list.append(cv_scores[k])
    
plt.plot(k_range,cv_scores_list)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
print(cv_scores_list)
# Out:
# [0.9853333333333334, 0.9773333333333335, 0.9673333333333334, 0.9566666666666667, 0.9493333333333333, 0.9433333333333334, 0.938, 0.9346666666666665, 0.9306666666666666, 0.9213333333333334, 0.9173333333333333, 0.916, 0.914, 0.9093333333333333, 0.9113333333333333, 0.9120000000000001, 0.9120000000000001, 0.9113333333333336, 0.9066666666666666, 0.9073333333333332, 0.9046666666666667, 0.9026666666666665, 0.9013333333333333, 0.8986666666666668, 0.8986666666666666, 0.8960000000000001, 0.8966666666666667, 0.8959999999999999, 0.8979999999999999, 0.89, 0.8826666666666668, 0.8806666666666668, 0.8753333333333334, 0.876, 0.8753333333333332, 0.876, 0.8753333333333334, 0.8753333333333334, 0.876, 0.8746666666666666, 0.8766666666666667, 0.8753333333333334, 0.8766666666666667, 0.8766666666666667, 0.876, 0.8773333333333333, 0.8766666666666667, 0.8766666666666666, 0.8766666666666666]

# %% [markdown]
# ### 3.2.3 Finding a value for K - Square root n
# n being the number of data points

# %%
print (math.sqrt(len(yTrain)))
# Out:
# 32.4037034920393

# %% [markdown]
# ### 3.2.4 Implementing K into KNN model
# Setting k to 31.

# %%
# Create our KNN classifier. Setting K to 31
knn = KNeighborsClassifier(n_neighbors = 31)
 
# Fit our trained data in the classifer
knn.fit (xTrain, yTrain)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=31, p=2,
#                      weights='uniform')

# %% [markdown]
# ### 3.2.5 Accuracy of KNN Model

# %%
# Check accuracy of our model
knn.score(xTest, yTest)

# %%
print(metrics.classification_report(yTest,yPred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88       294
#            1       0.81      0.67      0.73       156
#
#     accuracy                           0.83       450
#    macro avg       0.82      0.79      0.81       450
# weighted avg       0.83      0.83      0.83       450

# %% [markdown]
# ## 3.3 Decision Tree Model
# https://towardsdatascience.com/scikit-learn-decision-trees-explained-803f3812290d

# %% [markdown]
# ### 3.3.1 Implementing Decision Tree Model

# %%
clf = tree.DecisionTreeClassifier(max_depth = 7)
clf = clf.fit(xTrain, yTrain)
plt.rcParams["figure.figsize"] = (20,20)
tree.plot_tree(clf)
# Out:
# [Text(778.875, 1019.25, 'X[9] <= 0.5\ngini = 0.441\nsamples = 1050\nvalue = [706, 344]'),
#  Text(551.1617647058823, 883.35, 'X[1] <= 74.0\ngini = 0.271\nsamples = 835\nvalue = [700, 135]'),
#  Text(358.3235294117647, 747.45, 'X[0] <= 87.5\ngini = 0.099\nsamples = 651\nvalue = [617, 34]'),
#  Text(235.23529411764707, 611.55, 'X[1] <= 61.0\ngini = 0.056\nsamples = 590\nvalue = [573, 17]'),
#  Text(142.23529411764707, 475.65, 'X[6] <= 0.5\ngini = 0.029\nsamples = 545\nvalue = [537, 8]'),
#  Text(87.52941176470588, 339.75, 'X[10] <= 0.5\ngini = 0.026\nsamples = 541\nvalue = [534, 7]'),
#  Text(43.76470588235294, 203.85000000000002, 'X[8] <= 0.5\ngini = 0.022\nsamples = 536\nvalue = [530, 6]'),
#  Text(21.88235294117647, 67.95000000000005, 'gini = 0.0\nsamples = 317\nvalue = [317, 0]'),
#  Text(65.64705882352942, 67.95000000000005, 'gini = 0.053\nsamples = 219\nvalue = [213, 6]'),
#  Text(131.29411764705884, 203.85000000000002, 'X[2] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(109.41176470588235, 67.95000000000005, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(153.1764705882353, 67.95000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(196.94117647058823, 339.75, 'X[4] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(175.05882352941177, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(218.8235294117647, 203.85000000000002, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(328.2352941176471, 475.65, 'X[8] <= 0.5\ngini = 0.32\nsamples = 45\nvalue = [36, 9]'),
#  Text(284.47058823529414, 339.75, 'X[6] <= 0.5\ngini = 0.059\nsamples = 33\nvalue = [32, 1]'),
#  Text(262.5882352941177, 203.85000000000002, 'gini = 0.0\nsamples = 32\nvalue = [32, 0]'),
#  Text(306.3529411764706, 203.85000000000002, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(372.0, 339.75, 'X[0] <= 77.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(350.11764705882354, 203.85000000000002, 'X[1] <= 67.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(328.2352941176471, 67.95000000000005, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(372.0, 67.95000000000005, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(393.88235294117646, 203.85000000000002, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(481.4117647058824, 611.55, 'X[7] <= 0.5\ngini = 0.402\nsamples = 61\nvalue = [44, 17]'),
#  Text(437.6470588235294, 475.65, 'X[6] <= 0.5\ngini = 0.046\nsamples = 42\nvalue = [41, 1]'),
#  Text(415.7647058823529, 339.75, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(459.5294117647059, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(525.1764705882354, 475.65, 'X[4] <= 0.5\ngini = 0.266\nsamples = 19\nvalue = [3, 16]'),
#  Text(503.29411764705884, 339.75, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(547.0588235294118, 339.75, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(744.0, 747.45, 'X[8] <= 0.5\ngini = 0.495\nsamples = 184\nvalue = [83, 101]'),
#  Text(656.4705882352941, 611.55, 'X[0] <= 87.5\ngini = 0.418\nsamples = 104\nvalue = [73, 31]'),
#  Text(612.7058823529412, 475.65, 'X[2] <= 0.5\ngini = 0.252\nsamples = 81\nvalue = [69, 12]'),
#  Text(590.8235294117648, 339.75, 'gini = 0.0\nsamples = 54\nvalue = [54, 0]'),
#  Text(634.5882352941177, 339.75, 'X[1] <= 85.0\ngini = 0.494\nsamples = 27\nvalue = [15, 12]'),
#  Text(612.7058823529412, 203.85000000000002, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(656.4705882352941, 203.85000000000002, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(700.2352941176471, 475.65, 'X[1] <= 87.5\ngini = 0.287\nsamples = 23\nvalue = [4, 19]'),
#  Text(678.3529411764706, 339.75, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(722.1176470588235, 339.75, 'X[7] <= 0.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(700.2352941176471, 203.85000000000002, 'X[1] <= 92.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(678.3529411764706, 67.95000000000005, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(722.1176470588235, 67.95000000000005, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(744.0, 203.85000000000002, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(831.5294117647059, 611.55, 'X[0] <= 65.0\ngini = 0.219\nsamples = 80\nvalue = [10, 70]'),
#  Text(787.7647058823529, 475.65, 'X[6] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(765.8823529411765, 339.75, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(809.6470588235294, 339.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(875.2941176470588, 475.65, 'X[5] <= 0.5\ngini = 0.149\nsamples = 74\nvalue = [6, 68]'),
#  Text(853.4117647058823, 339.75, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(897.1764705882354, 339.75, 'X[0] <= 85.5\ngini = 0.337\nsamples = 28\nvalue = [6, 22]'),
#  Text(875.2941176470588, 203.85000000000002, 'X[7] <= 0.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(853.4117647058823, 67.95000000000005, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(897.1764705882354, 67.95000000000005, 'gini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(919.0588235294118, 203.85000000000002, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(1006.5882352941177, 883.35, 'X[1] <= 32.5\ngini = 0.054\nsamples = 215\nvalue = [6, 209]'),
#  Text(962.8235294117648, 747.45, 'X[2] <= 0.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(940.9411764705883, 611.55, 'X[0] <= 83.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(919.0588235294118, 475.65, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(962.8235294117648, 475.65, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(984.7058823529412, 611.55, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1050.3529411764707, 747.45, 'X[5] <= 0.5\ngini = 0.01\nsamples = 205\nvalue = [1, 204]'),
#  Text(1028.4705882352941, 611.55, 'gini = 0.0\nsamples = 197\nvalue = [0, 197]'),
#  Text(1072.235294117647, 611.55, 'X[7] <= 0.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(1050.3529411764707, 475.65, 'X[6] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(1028.4705882352941, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1072.235294117647, 339.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1094.1176470588236, 475.65, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]')]

# %% [markdown]
# ### 3.3.2 Accuracy of Decision Tree Model

# %%
yPred = clf.predict(xTest)
print("Accuracy:",metrics.accuracy_score(yTest, yPred))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, yPred))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,yPred))
# Out:
# Accuracy: 0.9822222222222222
# Mean Absolute Error: 0.017777777777777778
# Mean Squared Error: 0.017777777777777778

# %%
plt.rcParams["figure.figsize"] = (10,10)
skplt.metrics.plot_confusion_matrix(y_true= yTest, y_pred = yPred)

# %% [markdown]
# ## 3.4 Multi-Layer Perceptron

# %% [markdown]
# ### 3.4.1 Implementing Multi-Layer Perceptron

# %%
model = MLPClassifier(solver='sgd',activation='logistic',max_iter=5000000, hidden_layer_sizes=(400))
trained_model = model.fit(xTrain,yTrain)
model_prediction = trained_model.predict(xTest)

# %%
skplt.metrics.plot_confusion_matrix(y_true = yTest, y_pred = model_prediction)

# %% [markdown]
# ### 3.4.2 Accuracy of Multi-Layer Perceptron

# %%
metrics.accuracy_score(yTest,model_prediction)
# Out:
# 0.8955555555555555

# %% [markdown]
# # 4. Reinspection of data

# %% [markdown]
# ### 4.1 Heatmap of our variables

# %%
sb.heatmap(data_copy.corr(),annot=True,fmt = '.2g')

# %% [markdown]
# The heatmap above suggests that compared to 'label_bool', the Indication values and History have little to no coorelation.

# %%
data_copy=data_copy.drop(columns=['History_bool','Indication_A-F','Indication_ASX','Indication_CVA','Indication_TIA'])
data_copy.head()
# Out:
#    IPSI Contra  Diabetes_bool  IHD_bool  Hypertension_bool  Arrhythmia_bool  \
# 0  78.0    20           False     False               True            False
# 1  70.0    60           False     False              False            False
# 2  95.0     40          False      True               True            False
# 3  90.0     85          False     False               True            False
# 4  70.0    20           False     False              False            False
#
#    label_bool
# 0           0
# 1           0
# 2           1
# 3           1
# 4           0

# %% [markdown]
# # 5. Re-Run Models with new Data

# %% [markdown]
# ### Defining X & Y

# %%
# X contains all columns except label
X = data_copy.drop(columns=['label_bool'])

# Y contains label values.
Y = data_copy['label_bool'].values

# %% [markdown]
# ### Create train test split

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, shuffle=True)

# %% [markdown]
# ## KNN Model

# %%
# Create our KNN classifier. Setting K to 31
knn = KNeighborsClassifier(n_neighbors = 31)
 
# Fit our trained data in the classifer
knn.fit (xTrain, yTrain)

# Check accuracy of our model 
knn.score(xTest, yTest)
# Out:
# 0.8866666666666667

# %%
print(metrics.classification_report(yTest,yPred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.66      0.66       300
#            1       0.33      0.34      0.34       150
#
#     accuracy                           0.55       450
#    macro avg       0.50      0.50      0.50       450
# weighted avg       0.55      0.55      0.55       450

# %% [markdown]
# ## Decision Tree Model

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(xTrain, yTrain)
plt.rcParams["figure.figsize"] = (20,20)
tree.plot_tree(clf)
# Out:
# [Text(707.8954326923076, 1045.3846153846155, 'X[5] <= 0.5\ngini = 0.444\nsamples = 1050\nvalue = [700, 350]'),
#  Text(460.7524038461538, 961.7538461538462, 'X[1] <= 61.0\ngini = 0.279\nsamples = 831\nvalue = [692, 139]'),
#  Text(241.44230769230768, 878.123076923077, 'X[0] <= 87.5\ngini = 0.077\nsamples = 595\nvalue = [571, 24]'),
#  Text(118.03846153846153, 794.4923076923078, 'X[3] <= 0.5\ngini = 0.04\nsamples = 537\nvalue = [526, 11]'),
#  Text(96.57692307692307, 710.8615384615384, 'gini = 0.0\nsamples = 308\nvalue = [308, 0]'),
#  Text(139.5, 710.8615384615384, 'X[4] <= 0.5\ngini = 0.091\nsamples = 229\nvalue = [218, 11]'),
#  Text(42.92307692307692, 627.2307692307693, 'X[0] <= 79.5\ngini = 0.015\nsamples = 136\nvalue = [135, 1]'),
#  Text(21.46153846153846, 543.6, 'gini = 0.0\nsamples = 106\nvalue = [106, 0]'),
#  Text(64.38461538461539, 543.6, 'X[1] <= 45.0\ngini = 0.064\nsamples = 30\nvalue = [29, 1]'),
#  Text(42.92307692307692, 459.96923076923076, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(85.84615384615384, 459.96923076923076, 'X[0] <= 80.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(64.38461538461539, 376.3384615384616, 'X[1] <= 50.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(42.92307692307692, 292.70769230769235, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(85.84615384615384, 292.70769230769235, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(107.30769230769229, 376.3384615384616, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(236.07692307692307, 627.2307692307693, 'X[1] <= 25.0\ngini = 0.192\nsamples = 93\nvalue = [83, 10]'),
#  Text(214.61538461538458, 543.6, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(257.53846153846155, 543.6, 'X[2] <= 0.5\ngini = 0.282\nsamples = 59\nvalue = [49, 10]'),
#  Text(236.07692307692307, 459.96923076923076, 'X[1] <= 37.5\ngini = 0.262\nsamples = 58\nvalue = [49, 9]'),
#  Text(150.23076923076923, 376.3384615384616, 'X[0] <= 75.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(128.76923076923077, 292.70769230769235, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(171.69230769230768, 292.70769230769235, 'X[1] <= 32.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(150.23076923076923, 209.0769230769231, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(193.15384615384613, 209.0769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(321.9230769230769, 376.3384615384616, 'X[0] <= 78.0\ngini = 0.19\nsamples = 47\nvalue = [42, 5]'),
#  Text(257.53846153846155, 292.70769230769235, 'X[0] <= 75.5\ngini = 0.062\nsamples = 31\nvalue = [30, 1]'),
#  Text(236.07692307692307, 209.0769230769231, 'X[0] <= 72.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(214.61538461538458, 125.44615384615383, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(257.53846153846155, 125.44615384615383, 'X[1] <= 55.0\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(236.07692307692307, 41.81538461538457, 'gini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(279.0, 41.81538461538457, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(279.0, 209.0769230769231, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(386.30769230769226, 292.70769230769235, 'X[1] <= 55.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(364.8461538461538, 209.0769230769231, 'X[0] <= 82.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(343.38461538461536, 125.44615384615383, 'X[1] <= 45.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(321.9230769230769, 41.81538461538457, 'gini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(364.8461538461538, 41.81538461538457, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(386.30769230769226, 125.44615384615383, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(407.7692307692307, 209.0769230769231, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(279.0, 459.96923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(364.8461538461538, 794.4923076923078, 'X[4] <= 0.5\ngini = 0.348\nsamples = 58\nvalue = [45, 13]'),
#  Text(343.38461538461536, 710.8615384615384, 'X[2] <= 0.5\ngini = 0.081\nsamples = 47\nvalue = [45, 2]'),
#  Text(321.9230769230769, 627.2307692307693, 'X[1] <= 55.0\ngini = 0.043\nsamples = 46\nvalue = [45, 1]'),
#  Text(300.46153846153845, 543.6, 'gini = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(343.38461538461536, 543.6, 'X[3] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(321.9230769230769, 459.96923076923076, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(364.8461538461538, 459.96923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(364.8461538461538, 627.2307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(386.30769230769226, 710.8615384615384, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(680.0625, 878.123076923077, 'X[4] <= 0.5\ngini = 0.5\nsamples = 236\nvalue = [121, 115]'),
#  Text(566.0480769230769, 794.4923076923078, 'X[0] <= 87.5\ngini = 0.354\nsamples = 139\nvalue = [107, 32]'),
#  Text(466.7884615384615, 710.8615384615384, 'X[1] <= 87.5\ngini = 0.212\nsamples = 116\nvalue = [102, 14]'),
#  Text(407.7692307692307, 627.2307692307693, 'X[2] <= 0.5\ngini = 0.027\nsamples = 74\nvalue = [73, 1]'),
#  Text(386.30769230769226, 543.6, 'gini = 0.0\nsamples = 73\nvalue = [73, 0]'),
#  Text(429.23076923076917, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(525.8076923076923, 627.2307692307693, 'X[0] <= 77.5\ngini = 0.427\nsamples = 42\nvalue = [29, 13]'),
#  Text(472.15384615384613, 543.6, 'X[3] <= 0.5\ngini = 0.257\nsamples = 33\nvalue = [28, 5]'),
#  Text(429.23076923076917, 459.96923076923076, 'X[0] <= 72.5\ngini = 0.128\nsamples = 29\nvalue = [27, 2]'),
#  Text(407.7692307692307, 376.3384615384616, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(450.6923076923077, 376.3384615384616, 'X[1] <= 95.0\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(429.23076923076917, 292.70769230769235, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(472.15384615384613, 292.70769230769235, 'gini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(515.0769230769231, 459.96923076923076, 'X[0] <= 71.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(493.6153846153846, 376.3384615384616, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(536.5384615384615, 376.3384615384616, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(579.4615384615385, 543.6, 'X[1] <= 95.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(558.0, 459.96923076923076, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(600.9230769230769, 459.96923076923076, 'X[3] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(579.4615384615385, 376.3384615384616, 'X[0] <= 82.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(558.0, 292.70769230769235, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(600.9230769230769, 292.70769230769235, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(622.3846153846154, 376.3384615384616, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(665.3076923076923, 710.8615384615384, 'X[1] <= 87.5\ngini = 0.34\nsamples = 23\nvalue = [5, 18]'),
#  Text(643.8461538461538, 627.2307692307693, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(686.7692307692307, 627.2307692307693, 'X[3] <= 0.5\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(665.3076923076923, 543.6, 'X[1] <= 92.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(643.8461538461538, 459.96923076923076, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(686.7692307692307, 459.96923076923076, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(708.2307692307692, 543.6, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(794.076923076923, 794.4923076923078, 'X[0] <= 67.5\ngini = 0.247\nsamples = 97\nvalue = [14, 83]'),
#  Text(751.1538461538461, 710.8615384615384, 'X[2] <= 0.5\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(729.6923076923076, 627.2307692307693, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(772.6153846153845, 627.2307692307693, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(836.9999999999999, 710.8615384615384, 'X[0] <= 77.5\ngini = 0.131\nsamples = 85\nvalue = [6, 79]'),
#  Text(815.5384615384614, 627.2307692307693, 'X[3] <= 0.5\ngini = 0.328\nsamples = 29\nvalue = [6, 23]'),
#  Text(794.076923076923, 543.6, 'X[1] <= 67.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(772.6153846153845, 459.96923076923076, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(815.5384615384614, 459.96923076923076, 'X[1] <= 87.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(794.076923076923, 376.3384615384616, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(836.9999999999999, 376.3384615384616, 'X[0] <= 72.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(815.5384615384614, 292.70769230769235, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(858.4615384615383, 292.70769230769235, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(836.9999999999999, 543.6, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(858.4615384615383, 627.2307692307693, 'gini = 0.0\nsamples = 56\nvalue = [0, 56]'),
#  Text(955.0384615384614, 961.7538461538462, 'X[1] <= 42.5\ngini = 0.07\nsamples = 219\nvalue = [8, 211]'),
#  Text(879.9230769230769, 878.123076923077, 'X[0] <= 78.0\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(858.4615384615383, 794.4923076923078, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(901.3846153846154, 794.4923076923078, 'X[0] <= 85.0\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(879.9230769230769, 710.8615384615384, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(922.8461538461538, 710.8615384615384, 'X[3] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(901.3846153846154, 627.2307692307693, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(944.3076923076923, 627.2307692307693, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1030.1538461538462, 878.123076923077, 'X[0] <= 72.5\ngini = 0.019\nsamples = 208\nvalue = [2, 206]'),
#  Text(987.2307692307692, 794.4923076923078, 'X[4] <= 0.5\ngini = 0.105\nsamples = 18\nvalue = [1, 17]'),
#  Text(965.7692307692307, 710.8615384615384, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1008.6923076923076, 710.8615384615384, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(1073.076923076923, 794.4923076923078, 'X[0] <= 82.5\ngini = 0.01\nsamples = 190\nvalue = [1, 189]'),
#  Text(1051.6153846153845, 710.8615384615384, 'X[3] <= 0.5\ngini = 0.034\nsamples = 58\nvalue = [1, 57]'),
#  Text(1030.1538461538462, 627.2307692307693, 'X[0] <= 77.5\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(1008.6923076923076, 543.6, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(1051.6153846153845, 543.6, 'X[1] <= 90.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(1030.1538461538462, 459.96923076923076, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1073.076923076923, 459.96923076923076, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(1073.076923076923, 627.2307692307693, 'gini = 0.0\nsamples = 43\nvalue = [0, 43]'),
#  Text(1094.5384615384614, 710.8615384615384, 'gini = 0.0\nsamples = 132\nvalue = [0, 132]')]

# %%
yPred = clf.predict(xTest)
print("Accuracy:",metrics.accuracy_score(yTest, yPred))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, yPred))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,yPred))
# Out:
# Accuracy: 0.9844444444444445
# Mean Absolute Error: 0.015555555555555555
# Mean Squared Error: 0.015555555555555555

# %%
plt.rcParams["figure.figsize"] = (10,10)
skplt.metrics.plot_confusion_matrix(y_true= yTest, y_pred = yPred)

# %% [markdown]
# ## Multi-Layer Perceptron

# %%
model = MLPClassifier(solver='sgd',activation='logistic',max_iter=5000000, hidden_layer_sizes=(400))
trained_model = model.fit(xTrain,yTrain)
model_prediction = trained_model.predict(xTest)

skplt.metrics.plot_confusion_matrix(y_true = yTest, y_pred = model_prediction)

# %%
metrics.accuracy_score(yTest,model_prediction)
# Out:
# 0.9133333333333333
