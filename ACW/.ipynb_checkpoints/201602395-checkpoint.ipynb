# %%
import time
import math
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import scikitplot as skplt
import sklearn 

from sklearn import tree
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

from pylab import rcParams

from sklearn.neural_network import MLPClassifier

# %matplotlib inline

#pip install matplotlib==3.1.0 --upgrade --force to fix confusion matrix issue

#https://towardsdatascience.com/knn-using-scikit-learn-c6bed765be75
#https://towardsdatascience.com/building-a-k-nearest-neighbors-k-nn-model-with-scikit-learn-51209555453a

#clf = tree.DecisionTreeClassifier()
#clf = clf.fit(data_copy, data_copy.target)
#tree.plot_tree(clf)

# %%
data = pd.read_csv('600092_data.csv')

# %% [markdown]
# # 1.0 Understanding the Data

# %%
data_copy = data
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 11 columns):
# Random          1520 non-null float64
# Id              1520 non-null int64
# Indication      1517 non-null object
# Diabetes        1518 non-null object
# IHD             1520 non-null object
# Hypertension    1517 non-null object
# Arrhythmia      1520 non-null object
# History         1518 non-null object
# IPSI            1516 non-null float64
# Contra          1520 non-null object
# label           1517 non-null object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 83.2+ KB

# %%
data_copy.head()
# Out:
#      Random      Id Indication Diabetes  IHD Hypertension Arrhythmia History  \
# 0  0.602437  218242        A-F       no   no          yes         no      no
# 1  0.602437  159284        TIA       no   no           no         no      no
# 2  0.602437  106066        A-F       no  yes          yes         no      no
# 3  0.128157  229592        TIA       no   no          yes         no      no
# 4  0.676862  245829        CVA       no   no           no         no      no
#
#    IPSI Contra   label
# 0  78.0    20   NoRisk
# 1  70.0    60   NoRisk
# 2  95.0     40    Risk
# 3  90.0     85    Risk
# 4  70.0    20   NoRisk

# %% [markdown]
# # 2.0 Inspecting and Cleaning the Data
# ### 2.1 Removing Null Values

# %%
data_copy.isna().sum()
# Out:
# Random          0
# Id              0
# Indication      3
# Diabetes        2
# IHD             0
# Hypertension    3
# Arrhythmia      0
# History         2
# IPSI            4
# Contra          0
# label           3
# dtype: int64

# %%
data_copy.dropna(inplace=True)

# %%
data_copy.isna().sum()
# Out:
# Random          0
# Id              0
# Indication      0
# Diabetes        0
# IHD             0
# Hypertension    0
# Arrhythmia      0
# History         0
# IPSI            0
# Contra          0
# label           0
# dtype: int64

# %% [markdown]
# ### 2.2 Inspecting column Random

# %%
data_copy['Random'].value_counts(dropna=False)
# Out:
# 0.683506    4
# 0.506597    4
# 0.576184    4
# 0.899742    4
# 0.803415    3
#            ..
# 0.346396    1
# 0.801775    1
# 0.972183    1
# 0.692722    1
# 0.219026    1
# Name: Random, Length: 1212, dtype: int64

# %% [markdown]
# ### 2.3 Removing column Random

# %%
data_copy = data_copy.drop(columns=['Random'])

# %% [markdown]
# ### 2.4 Inspecting column Id
# #### This column should contain uniques. Checking for duplicates

# %%
duplicateIdDF = data_copy[data_copy.duplicated(['Id'])]

if duplicateIdDF.empty :
    print ("No Duplicates")
else:
    print (duplicateIdDF)
# Out:
# No Duplicates

# %% [markdown]
# #### Removing column Id
# No duplicates are present. Therefore it is assumed all data is unique. No further use for ID column and therefore dropping.

# %%
data_copy = data_copy.drop(columns=['Id'])

# %% [markdown]
# ### 2.5 Inspecting column Indication

# %%
data_copy['Indication'].value_counts(dropna=False)
# Out:
# A-F    489
# CVA    408
# TIA    388
# ASx    186
# Asx     32
# Name: Indication, dtype: int64

# %% [markdown]
# #### Setting all values to upper case
# As seen above, we are reading 5 different values for Indication when there should only be 4.
# This is due to two values being the same but having different capitialisation.
# Setting all values in our data to uppercase to solve this and avoid any further errors.

# %%
# Change all my string data to Uppercase to avoid any
data_copy['Indication'] = data_copy['Indication'].str.upper()
data_copy['Diabetes'] = data_copy['Diabetes'].str.upper() 
data_copy['IHD'] = data_copy['IHD'].str.upper() 
data_copy['Hypertension'] = data_copy['Hypertension'].str.upper() 
data_copy['Arrhythmia'] = data_copy['Arrhythmia'].str.upper() 
data_copy['History'] = data_copy['History'].str.upper() 
data_copy['label'] = data_copy['label'].str.upper() 

data_copy['Indication'].value_counts(dropna=False)
# Out:
# A-F    489
# CVA    408
# TIA    388
# ASX    218
# Name: Indication, dtype: int64

# %%
# Displays count Indication graph

#sb.countplot(data = data_copy, x= "Indication")
#y = plt.ylabel("Amount of People")
#sb.catplot('label', col="Indication", data = data_copy,kind='count' , height = 2.5)

# %% [markdown]
# #### One Hot Encoding - Indication
# Using One Hot Encoding to split Indication into 4 boolean columns to prevent the data being misinterpreted later on in other algorithms.
# https://pbpython.com/categorical-encoding.html

# %%
data_copy = pd.get_dummies(data_copy, columns=["Indication"])
data_copy.head()
# Out:
#   Diabetes  IHD Hypertension Arrhythmia History  IPSI Contra   label  \
# 0       NO   NO          YES         NO      NO  78.0    20   NORISK
# 1       NO   NO           NO         NO      NO  70.0    60   NORISK
# 2       NO  YES          YES         NO      NO  95.0     40    RISK
# 3       NO   NO          YES         NO      NO  90.0     85    RISK
# 4       NO   NO           NO         NO      NO  70.0    20   NORISK
#
#    Indication_A-F  Indication_ASX  Indication_CVA  Indication_TIA
# 0               1               0               0               0
# 1               0               0               0               1
# 2               1               0               0               0
# 3               0               0               0               1
# 4               0               0               1               0

# %% [markdown]
# ### 2.6 Inspecting each binary column.

# %%
data_copy['Diabetes'].value_counts(dropna=False)
# Out:
# NO     1428
# YES      75
# Name: Diabetes, dtype: int64

# %%
data_copy['IHD'].value_counts(dropna=False)
# Out:
# NO     791
# YES    712
# Name: IHD, dtype: int64

# %%
data_copy['Hypertension'].value_counts(dropna=False)
# Out:
# NO     777
# YES    726
# Name: Hypertension, dtype: int64

# %%
data_copy['Arrhythmia'].value_counts(dropna=False)
# Out:
# NO     1179
# YES     324
# Name: Arrhythmia, dtype: int64

# %%
data_copy['History'].value_counts(dropna=False)
# Out:
# NO     1481
# YES      22
# Name: History, dtype: int64

# %% [markdown]
# #### Changing each binary column to display True for YES and False for NO.
# Setting these values to true and false will make them readable to algorithms and models later on

# %%
# Creating a map to change YES and NO to True and False respectively
yesToTrue = {'YES': True,'NO': False}

# Creating new columns in our data, Displaying True or False instead
data_copy = data_copy.assign(Diabetes_bool = data_copy['Diabetes'].map(yesToTrue),
                      IHD_bool = data_copy['IHD'].map(yesToTrue),
                      Hypertension_bool = data_copy['Hypertension'].map(yesToTrue),
                      Arrhythmia_bool = data_copy['Arrhythmia'].map(yesToTrue),
                      History_bool = data_copy['History'].map(yesToTrue))

# Now dropping the old columns which displayed YES or NO
data_copy = data_copy.drop(columns=['Diabetes','IHD','Hypertension','Arrhythmia','History'])

data_copy.head()
# Out:
#    IPSI Contra   label  Indication_A-F  Indication_ASX  Indication_CVA  \
# 0  78.0    20   NORISK               1               0               0
# 1  70.0    60   NORISK               0               0               0
# 2  95.0     40    RISK               1               0               0
# 3  90.0     85    RISK               0               0               0
# 4  70.0    20   NORISK               0               0               1
#
#    Indication_TIA  Diabetes_bool  IHD_bool  Hypertension_bool  \
# 0               0          False     False               True
# 1               1          False     False              False
# 2               0          False      True               True
# 3               1          False     False               True
# 4               0          False     False              False
#
#    Arrhythmia_bool  History_bool
# 0            False         False
# 1            False         False
# 2            False         False
# 3            False         False
# 4            False         False

# %% [markdown]
# ### 2.7 Inspecting column IPSI

# %%
data_copy['IPSI'].value_counts(dropna=False)
# Out:
# 70.0    230
# 75.0    221
# 80.0    185
# 90.0    173
# 95.0    155
# 73.0     83
# 85.0     76
# 76.0     74
# 78.0     49
# 68.0     32
# 99.0     30
# 60.0     29
# 81.0     28
# 82.0     25
# 50.0     23
# 65.0     14
# 71.0     13
# 79.0     13
# 77.0      9
# 55.0      9
# 74.0      7
# 97.0      7
# 51.0      7
# 69.0      3
# 84.0      2
# 72.0      2
# 67.0      2
# 98.0      1
# 35.0      1
# Name: IPSI, dtype: int64

# %% [markdown]
# ### 2.8 Inspecting column Contra

# %%
data_copy['Contra'].value_counts(dropna=False)
# Out:
# 100     238
# 20      191
# 30      150
# 50      131
# 40      101
# 60       93
# 50       51
# 10       49
# 100      39
# 90       34
# 70       34
# 95       32
# 75       31
# 25       30
# 75       29
# 80       29
# 80       24
# 85       24
# 35       22
# 15       18
# 70       18
# 55       14
# 65       13
# 30       12
# 85       11
# 51       11
# 90       10
# 53        9
# 55        9
# 40        7
# 73        7
# 45        6
# 60        6
# 35        5
# 65        4
# 16        4
# 62        3
# 79        2
# 10        1
#           1
# Name: Contra, dtype: int64

# %% [markdown]
# #### Compare column Contra to IPSI
# An empty value is present in Contra.
# Will compare to IPSI to see if any coorelation is present.

# %%
colour = data_copy.label.map({'RISK':'b','NORISK':'r', 'UNKNOWN':'g', 'NAN':'y' })
ax1 = plt.scatter(data_copy['Contra'], data_copy['IPSI'],c= colour)
ax1.axes.set_ylabel('IPSI')
ax1.axes.set_xlabel('Contra')
# Out:
# Text(0.5, 0, 'Contra')

# %% [markdown]
# #### Turning empty value in Contra to NaN
# No correlation was found between Contra and IPSI alone. Therefore changing the value to NaN and will drop later.

# %%
data_copy=data_copy.replace(r'^\s*$', np.nan, regex=True)
data_copy.dropna(inplace=True)

# %% [markdown]
# #### Changing type of Contra to int

# %%
data_copy['Contra'] = data_copy['Contra'].str.strip('Contra').astype('int64')

# %% [markdown]
# ### 2.9 Inspect column label

# %%
data_copy['label'].value_counts(dropna=False)
# Out:
# NORISK     1000
# RISK        500
# UNKNOWN       2
# Name: label, dtype: int64

# %% [markdown]
# #### Removing records contain UNKNOWN
# Column lable contains two UNKNOWN values.
# Changing these to NaN and dropping

# %%
data_copy['label'] = data_copy['label'].replace("UNKNOWN", np.nan)
data_copy.dropna(inplace=True)

# %%
# Creating a map to change YES and NO to True and False respectively
riskToTrue = {'RISK': 1,'NORISK': 0}

data_copy = data_copy.assign(label_bool = data_copy['label'].map(riskToTrue))
data_copy = data_copy.drop(columns=['label'])
data_copy.head()
# Out:
#    IPSI  Contra  Indication_A-F  Indication_ASX  Indication_CVA  \
# 0  78.0      20               1               0               0
# 1  70.0      60               0               0               0
# 2  95.0      40               1               0               0
# 3  90.0      85               0               0               0
# 4  70.0      20               0               0               1
#
#    Indication_TIA  Diabetes_bool  IHD_bool  Hypertension_bool  \
# 0               0          False     False               True
# 1               1          False     False              False
# 2               0          False      True               True
# 3               1          False     False               True
# 4               0          False     False              False
#
#    Arrhythmia_bool  History_bool  label_bool
# 0            False         False           0
# 1            False         False           0
# 2            False         False           1
# 3            False         False           1
# 4            False         False           0

# %% [markdown]
# # 3.0 Data Models
# Will be creating multiple models to analyse the data.
# These models will be using a 70%-30% split of training and test data respectively.
#
# ## 3.1 Defining Test and Training Data
# ### Define X & Y.
# X being our cleaned and filtered data without the label column.
# Y being our label values.

# %%
# Define our x and y values for our training model
# X contains all columns except label
X = data_copy.drop(columns=['label_bool'])

# Y contains label values.
Y = data_copy['label_bool'].values

# %% [markdown]
# ### Create train test split
# Once we have our X and Y, we can split our data into 30% test data and 70% training data

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, shuffle=True)

# %% [markdown]
# ## 3.2 Nearest Neighbour Model (KNN)
# https://towardsdatascience.com/building-a-k-nearest-neighbors-k-nn-model-with-scikit-learn-51209555453a
# https://towardsdatascience.com/knn-using-scikit-learn-c6bed765be75
# https://www.quora.com/How-can-I-choose-the-best-K-in-KNN-K-nearest-neighbour-classification
# KNN model requires a value K. K determines how many neighbours are used to decide a given value.
#
# To find the best value for K, we will create multiple KNN models with different K values and inspect each of their accuracies.

# %% [markdown]
# ### 3.2.1 Finding a value for K - Using Predictor

# %%
k_range = range(1,50)
knn_scores = {}
knn_scores_list = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k, metric ='euclidean')
    knn.fit(xTrain,yTrain)
    yPred = knn.predict(xTest)
    knn_scores[k] = metrics.accuracy_score(yTest,yPred)
    knn_scores_list.append(metrics.accuracy_score(yTest,yPred))

# %%
plt.plot(k_range,knn_scores_list)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
print(knn_scores_list)
## 0.98, 0.9822, 0.991, 0.984
# Out:
# [0.9822222222222222, 0.9711111111111111, 0.9666666666666667, 0.9488888888888889, 0.9422222222222222, 0.9311111111111111, 0.9222222222222223, 0.9288888888888889, 0.9222222222222223, 0.9333333333333333, 0.9222222222222223, 0.9244444444444444, 0.92, 0.92, 0.9244444444444444, 0.9244444444444444, 0.9022222222222223, 0.9066666666666666, 0.9022222222222223, 0.9088888888888889, 0.9066666666666666, 0.9044444444444445, 0.9, 0.9066666666666666, 0.9044444444444445, 0.8977777777777778, 0.8844444444444445, 0.8844444444444445, 0.8888888888888888, 0.8888888888888888, 0.8955555555555555, 0.9, 0.8955555555555555, 0.8955555555555555, 0.8977777777777778, 0.8977777777777778, 0.8977777777777778, 0.9, 0.9, 0.9022222222222223, 0.9, 0.9, 0.9022222222222223, 0.8822222222222222, 0.8555555555555555, 0.8577777777777778, 0.8577777777777778, 0.8577777777777778, 0.8577777777777778]

# %% [markdown]
# ### 3.2.3 Finding a value for K - Square root n
# n being the number of data points

# %%
print (math.sqrt(len(yTrain)))
# Out:
# 32.4037034920393

# %% [markdown]
# ### 3.2.4 Implementing K into KNN model
# Setting k to 31.

# %%
# Create our KNN classifier. Setting K to 31
knn = KNeighborsClassifier(n_neighbors = 31)
 
# Fit our trained data in the classifer
knn.fit (xTrain, yTrain)

# Create our predictor
yPred = knn.predict(xTest)

# %% [markdown]
# ### 3.2.5 Accuracy of KNN Model

# %%
# Check accuracy of our model
print("Accuracy:",metrics.accuracy_score(yTest, yPred))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, yPred))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,yPred))
# Out:
# Accuracy: 0.8955555555555555
# Mean Absolute Error: 0.10444444444444445
# Mean Squared Error: 0.10444444444444445

# %%
print(metrics.classification_report(yTest,yPred))
print("KNN Model with K set to 31")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       293
#            1       0.86      0.83      0.85       157
#
#     accuracy                           0.90       450
#    macro avg       0.89      0.88      0.88       450
# weighted avg       0.89      0.90      0.90       450
#
# KNN Model with K set to 31

# %% [markdown]
# ### 3.2.6 Implementing KNN model with k-Fold Cross Validation

# %%
knn = KNeighborsClassifier(n_neighbors=31, metric ='euclidean')

cv_scores = cross_val_score(knn, X, Y, cv=5)
print(np.mean(cv_scores))
# Out:
# 0.8766666666666666

# %% [markdown]
# ## 3.3 Decision Tree Model
# https://towardsdatascience.com/scikit-learn-decision-trees-explained-803f3812290d
# https://towardsdatascience.com/decision-tree-classification-de64fc4d5aac

# %% [markdown]
# ### 3.3.1 Implementing Decision Tree Model

# %%
clf = tree.DecisionTreeClassifier(max_depth = 4)
clf = clf.fit(xTrain, yTrain)
plt.rcParams["figure.figsize"] = (20,20)
tree.plot_tree(clf)
# Out:
# [Text(587.8928571428571, 978.48, 'X[9] <= 0.5\ngini = 0.44\nsamples = 1050\nvalue = [707, 343]'),
#  Text(318.85714285714283, 761.0400000000001, 'X[1] <= 74.0\ngini = 0.262\nsamples = 827\nvalue = [699, 128]'),
#  Text(159.42857142857142, 543.6, 'X[6] <= 0.5\ngini = 0.102\nsamples = 646\nvalue = [611, 35]'),
#  Text(79.71428571428571, 326.1600000000001, 'X[0] <= 84.5\ngini = 0.079\nsamples = 633\nvalue = [607, 26]'),
#  Text(39.857142857142854, 108.72000000000003, 'gini = 0.04\nsamples = 542\nvalue = [531, 11]'),
#  Text(119.57142857142856, 108.72000000000003, 'gini = 0.275\nsamples = 91\nvalue = [76, 15]'),
#  Text(239.1428571428571, 326.1600000000001, 'X[0] <= 75.0\ngini = 0.426\nsamples = 13\nvalue = [4, 9]'),
#  Text(199.28571428571428, 108.72000000000003, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(279.0, 108.72000000000003, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(478.2857142857142, 543.6, 'X[8] <= 0.5\ngini = 0.5\nsamples = 181\nvalue = [88, 93]'),
#  Text(398.57142857142856, 326.1600000000001, 'X[2] <= 0.5\ngini = 0.388\nsamples = 95\nvalue = [70, 25]'),
#  Text(358.71428571428567, 108.72000000000003, 'gini = 0.153\nsamples = 60\nvalue = [55, 5]'),
#  Text(438.4285714285714, 108.72000000000003, 'gini = 0.49\nsamples = 35\nvalue = [15, 20]'),
#  Text(558.0, 326.1600000000001, 'X[0] <= 65.0\ngini = 0.331\nsamples = 86\nvalue = [18, 68]'),
#  Text(518.1428571428571, 108.72000000000003, 'gini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(597.8571428571428, 108.72000000000003, 'gini = 0.157\nsamples = 70\nvalue = [6, 64]'),
#  Text(856.9285714285713, 761.0400000000001, 'X[1] <= 42.5\ngini = 0.069\nsamples = 223\nvalue = [8, 215]'),
#  Text(757.2857142857142, 543.6, 'X[2] <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(717.4285714285713, 326.1600000000001, 'X[7] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(677.5714285714286, 108.72000000000003, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(757.2857142857142, 108.72000000000003, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(797.1428571428571, 326.1600000000001, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(956.5714285714284, 543.6, 'X[5] <= 0.5\ngini = 0.019\nsamples = 213\nvalue = [2, 211]'),
#  Text(876.8571428571428, 326.1600000000001, 'X[0] <= 72.5\ngini = 0.01\nsamples = 201\nvalue = [1, 200]'),
#  Text(836.9999999999999, 108.72000000000003, 'gini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(916.7142857142857, 108.72000000000003, 'gini = 0.0\nsamples = 182\nvalue = [0, 182]'),
#  Text(1036.2857142857142, 326.1600000000001, 'X[7] <= 0.5\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(996.4285714285713, 108.72000000000003, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(1076.142857142857, 108.72000000000003, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]')]

# %% [markdown]
# ### 3.3.2 Accuracy of Decision Tree Model

# %%
yPred = clf.predict(xTest)
print("Accuracy:",metrics.accuracy_score(yTest, yPred))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, yPred))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,yPred))
print("Decision Tree Model")
# Out:
# Accuracy: 0.9222222222222223
# Mean Absolute Error: 0.07777777777777778
# Mean Squared Error: 0.07777777777777778
# Decision Tree Model

# %%
plt.rcParams["figure.figsize"] = (10,10)
skplt.metrics.plot_confusion_matrix(y_true= yTest, y_pred = yPred)

# %% [markdown]
# ## 3.4 Multi-Layer Perceptron

# %% [markdown]
# ### 3.4.1 Implementing Multi-Layer Perceptron

# %%
model = MLPClassifier(solver='sgd',activation='logistic',max_iter=5000000, hidden_layer_sizes=(400))
trained_model = model.fit(xTrain,yTrain)
model_prediction = trained_model.predict(xTest)

# %%
skplt.metrics.plot_confusion_matrix(y_true = yTest, y_pred = model_prediction)

# %% [markdown]
# ### 3.4.2 Accuracy of Multi-Layer Perceptron

# %%
metrics.accuracy_score(yTest,model_prediction)
print("Accuracy:",metrics.accuracy_score(yTest, model_prediction))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, model_prediction))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,model_prediction))
print("Decision Tree Model")
# Out:
# Accuracy: 0.9111111111111111
# Mean Absolute Error: 0.08888888888888889
# Mean Squared Error: 0.08888888888888889
# Decision Tree Model

# %% [markdown]
# # 4.0 Reinspection of data

# %% [markdown]
# ### 4.1 Heatmap of our variables

# %%
sb.heatmap(data_copy.corr(),annot=True,fmt = '.2g')

# %% [markdown]
# The heatmap above suggests that compared to 'label_bool', the Indication values and History have little to no coorelation.

# %%
data_copy=data_copy.drop(columns=['History_bool','Indication_A-F','Indication_ASX','Indication_CVA','Indication_TIA'])
data_copy.head()
# Out:
#    IPSI  Contra  Diabetes_bool  IHD_bool  Hypertension_bool  Arrhythmia_bool  \
# 0  78.0      20          False     False               True            False
# 1  70.0      60          False     False              False            False
# 2  95.0      40          False      True               True            False
# 3  90.0      85          False     False               True            False
# 4  70.0      20          False     False              False            False
#
#    label_bool
# 0           0
# 1           0
# 2           1
# 3           1
# 4           0

# %% [markdown]
# # 5.0 Re-Run Models with new Data

# %% [markdown]
# ### Defining X & Y

# %%
# X contains all columns except label
X = data_copy.drop(columns=['label_bool'])

# Y contains label values.
Y = data_copy['label_bool'].values

# %% [markdown]
# ### Create train test split

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, shuffle=True)

# %% [markdown]
# ## KNN Model

# %%
# Create our KNN classifier. Setting K to 31
knn = KNeighborsClassifier(n_neighbors = 31)
 
# Fit our trained data in the classifer
knn.fit (xTrain, yTrain)

# Check accuracy of our model 
knn.score(xTest, yTest)
# Out:
# 0.8711111111111111

# %%
print(metrics.classification_report(yTest,yPred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.69      0.69       306
#            1       0.32      0.31      0.32       144
#
#     accuracy                           0.57       450
#    macro avg       0.50      0.50      0.50       450
# weighted avg       0.57      0.57      0.57       450

# %% [markdown]
# ## Decision Tree Model

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(xTrain, yTrain)
plt.rcParams["figure.figsize"] = (20,20)
tree.plot_tree(clf)
# Out:
# [Text(657.2, 1048.3714285714286, 'X[5] <= 0.5\ngini = 0.448\nsamples = 1050\nvalue = [694, 356]'),
#  Text(409.2, 970.7142857142858, 'X[1] <= 74.0\ngini = 0.265\nsamples = 813\nvalue = [685, 128]'),
#  Text(235.6, 893.0571428571429, 'X[2] <= 0.5\ngini = 0.09\nsamples = 632\nvalue = [602, 30]'),
#  Text(148.8, 815.4000000000001, 'X[4] <= 0.5\ngini = 0.074\nsamples = 623\nvalue = [599, 24]'),
#  Text(49.6, 737.7428571428572, 'X[0] <= 97.0\ngini = 0.005\nsamples = 383\nvalue = [382, 1]'),
#  Text(24.8, 660.0857142857144, 'gini = 0.0\nsamples = 373\nvalue = [373, 0]'),
#  Text(74.4, 660.0857142857144, 'X[3] <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(49.6, 582.4285714285714, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(99.2, 582.4285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(248.0, 737.7428571428572, 'X[0] <= 87.5\ngini = 0.173\nsamples = 240\nvalue = [217, 23]'),
#  Text(223.20000000000002, 660.0857142857144, 'X[1] <= 61.0\ngini = 0.121\nsamples = 232\nvalue = [217, 15]'),
#  Text(148.8, 582.4285714285714, 'X[3] <= 0.5\ngini = 0.07\nsamples = 221\nvalue = [213, 8]'),
#  Text(124.0, 504.7714285714286, 'gini = 0.0\nsamples = 138\nvalue = [138, 0]'),
#  Text(173.6, 504.7714285714286, 'X[1] <= 25.0\ngini = 0.174\nsamples = 83\nvalue = [75, 8]'),
#  Text(148.8, 427.11428571428576, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(198.4, 427.11428571428576, 'X[1] <= 35.0\ngini = 0.273\nsamples = 49\nvalue = [41, 8]'),
#  Text(124.0, 349.4571428571429, 'X[0] <= 75.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(99.2, 271.80000000000007, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(148.8, 271.80000000000007, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(272.8, 349.4571428571429, 'X[0] <= 78.0\ngini = 0.219\nsamples = 40\nvalue = [35, 5]'),
#  Text(198.4, 271.80000000000007, 'X[0] <= 75.5\ngini = 0.074\nsamples = 26\nvalue = [25, 1]'),
#  Text(173.6, 194.14285714285722, 'X[0] <= 72.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(148.8, 116.48571428571427, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(198.4, 116.48571428571427, 'X[1] <= 45.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(173.6, 38.82857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(223.20000000000002, 38.82857142857142, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(223.20000000000002, 194.14285714285722, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(347.2, 271.80000000000007, 'X[1] <= 55.0\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(322.40000000000003, 194.14285714285722, 'X[0] <= 82.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(297.6, 116.48571428571427, 'X[1] <= 45.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(272.8, 38.82857142857142, 'gini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(322.40000000000003, 38.82857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(347.2, 116.48571428571427, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(372.0, 194.14285714285722, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(297.6, 582.4285714285714, 'X[0] <= 77.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(272.8, 504.7714285714286, 'X[1] <= 67.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(248.0, 427.11428571428576, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(297.6, 427.11428571428576, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(322.40000000000003, 504.7714285714286, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(272.8, 660.0857142857144, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(322.40000000000003, 815.4000000000001, 'X[1] <= 35.0\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(297.6, 737.7428571428572, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(347.2, 737.7428571428572, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(582.8000000000001, 893.0571428571429, 'X[4] <= 0.5\ngini = 0.497\nsamples = 181\nvalue = [83, 98]'),
#  Text(471.2, 815.4000000000001, 'X[1] <= 87.5\ngini = 0.42\nsamples = 100\nvalue = [70, 30]'),
#  Text(446.40000000000003, 737.7428571428572, 'gini = 0.0\nsamples = 46\nvalue = [46, 0]'),
#  Text(496.0, 737.7428571428572, 'X[0] <= 77.5\ngini = 0.494\nsamples = 54\nvalue = [24, 30]'),
#  Text(421.6, 660.0857142857144, 'X[3] <= 0.5\ngini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(396.8, 582.4285714285714, 'X[0] <= 72.5\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(372.0, 504.7714285714286, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(421.6, 504.7714285714286, 'X[1] <= 95.0\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(396.8, 427.11428571428576, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(446.40000000000003, 427.11428571428576, 'gini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(446.40000000000003, 582.4285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(570.4, 660.0857142857144, 'X[0] <= 92.5\ngini = 0.128\nsamples = 29\nvalue = [2, 27]'),
#  Text(545.6, 582.4285714285714, 'X[3] <= 0.5\ngini = 0.208\nsamples = 17\nvalue = [2, 15]'),
#  Text(520.8000000000001, 504.7714285714286, 'X[0] <= 87.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(496.0, 427.11428571428576, 'X[1] <= 95.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(471.2, 349.4571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(520.8000000000001, 349.4571428571429, 'X[0] <= 82.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(496.0, 271.80000000000007, 'gini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(545.6, 271.80000000000007, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(545.6, 427.11428571428576, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(570.4, 504.7714285714286, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(595.2, 582.4285714285714, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(694.4, 815.4000000000001, 'X[0] <= 65.0\ngini = 0.269\nsamples = 81\nvalue = [13, 68]'),
#  Text(644.8000000000001, 737.7428571428572, 'X[2] <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(620.0, 660.0857142857144, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(669.6, 660.0857142857144, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(744.0, 737.7428571428572, 'X[3] <= 0.5\ngini = 0.133\nsamples = 70\nvalue = [5, 65]'),
#  Text(719.2, 660.0857142857144, 'X[0] <= 77.5\ngini = 0.33\nsamples = 24\nvalue = [5, 19]'),
#  Text(694.4, 582.4285714285714, 'X[1] <= 87.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(669.6, 504.7714285714286, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(719.2, 504.7714285714286, 'X[0] <= 72.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(694.4, 427.11428571428576, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(744.0, 427.11428571428576, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(744.0, 582.4285714285714, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(768.8000000000001, 660.0857142857144, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(905.2, 970.7142857142858, 'X[1] <= 42.5\ngini = 0.073\nsamples = 237\nvalue = [9, 228]'),
#  Text(793.6, 893.0571428571429, 'X[0] <= 78.0\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(768.8000000000001, 815.4000000000001, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(818.4, 815.4000000000001, 'X[0] <= 85.0\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(793.6, 737.7428571428572, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(843.2, 737.7428571428572, 'X[3] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(818.4, 660.0857142857144, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(868.0, 660.0857142857144, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(1016.8000000000001, 893.0571428571429, 'X[0] <= 72.5\ngini = 0.018\nsamples = 224\nvalue = [2, 222]'),
#  Text(967.2, 815.4000000000001, 'X[4] <= 0.5\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(942.4, 737.7428571428572, 'X[1] <= 87.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(917.6, 660.0857142857144, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(967.2, 660.0857142857144, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(992.0, 737.7428571428572, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(1066.4, 815.4000000000001, 'X[0] <= 82.5\ngini = 0.01\nsamples = 204\nvalue = [1, 203]'),
#  Text(1041.6000000000001, 737.7428571428572, 'X[3] <= 0.5\ngini = 0.032\nsamples = 61\nvalue = [1, 60]'),
#  Text(1016.8000000000001, 660.0857142857144, 'X[0] <= 79.5\ngini = 0.095\nsamples = 20\nvalue = [1, 19]'),
#  Text(992.0, 582.4285714285714, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(1041.6000000000001, 582.4285714285714, 'X[1] <= 90.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(1016.8000000000001, 504.7714285714286, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(1066.4, 504.7714285714286, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(1066.4, 660.0857142857144, 'gini = 0.0\nsamples = 41\nvalue = [0, 41]'),
#  Text(1091.2, 737.7428571428572, 'gini = 0.0\nsamples = 143\nvalue = [0, 143]')]

# %%
yPred = clf.predict(xTest)
print("Accuracy:",metrics.accuracy_score(yTest, yPred))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, yPred))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,yPred))
# Out:
# Accuracy: 0.98
# Mean Absolute Error: 0.02
# Mean Squared Error: 0.02

# %%
plt.rcParams["figure.figsize"] = (10,10)
skplt.metrics.plot_confusion_matrix(y_true= yTest, y_pred = yPred)

# %% [markdown]
# ## Multi-Layer Perceptron

# %%
model = MLPClassifier(solver='sgd',activation='logistic',max_iter=5000000, hidden_layer_sizes=(400))
trained_model = model.fit(xTrain,yTrain)
model_prediction = trained_model.predict(xTest)

skplt.metrics.plot_confusion_matrix(y_true = yTest, y_pred = model_prediction)

# %%
metrics.accuracy_score(yTest,model_prediction)
# Out:
# 0.9111111111111111
