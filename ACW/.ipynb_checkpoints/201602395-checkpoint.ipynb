# %%
import time
import math
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import scikitplot as skplt
import sklearn 

from sklearn import tree
from sklearn import metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

from pylab import rcParams

from sklearn.neural_network import MLPClassifier

# %matplotlib inline

#pip install matplotlib==3.1.0 --upgrade --force to fix confusion matrix issue

#https://towardsdatascience.com/knn-using-scikit-learn-c6bed765be75
#https://towardsdatascience.com/building-a-k-nearest-neighbors-k-nn-model-with-scikit-learn-51209555453a

#clf = tree.DecisionTreeClassifier()
#clf = clf.fit(data_copy, data_copy.target)
#tree.plot_tree(clf)

# %%
data = pd.read_csv('600092_data.csv')

# %% [markdown]
# # 1.0 Understanding the Data

# %%
data_copy = data
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 11 columns):
# Random          1520 non-null float64
# Id              1520 non-null int64
# Indication      1517 non-null object
# Diabetes        1518 non-null object
# IHD             1520 non-null object
# Hypertension    1517 non-null object
# Arrhythmia      1520 non-null object
# History         1518 non-null object
# IPSI            1516 non-null float64
# Contra          1520 non-null object
# label           1517 non-null object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 83.2+ KB

# %%
data_copy.head()
# Out:
#      Random      Id Indication Diabetes  IHD Hypertension Arrhythmia History  \
# 0  0.602437  218242        A-F       no   no          yes         no      no
# 1  0.602437  159284        TIA       no   no           no         no      no
# 2  0.602437  106066        A-F       no  yes          yes         no      no
# 3  0.128157  229592        TIA       no   no          yes         no      no
# 4  0.676862  245829        CVA       no   no           no         no      no
#
#    IPSI Contra   label
# 0  78.0    20   NoRisk
# 1  70.0    60   NoRisk
# 2  95.0     40    Risk
# 3  90.0     85    Risk
# 4  70.0    20   NoRisk

# %% [markdown]
# # 2.0 Inspecting and Cleaning the Data
# ### 2.1 Removing Null Values

# %%
data_copy.isna().sum()
# Out:
# Random          0
# Id              0
# Indication      3
# Diabetes        2
# IHD             0
# Hypertension    3
# Arrhythmia      0
# History         2
# IPSI            4
# Contra          0
# label           3
# dtype: int64

# %%
data_copy.dropna(inplace=True)

# %%
data_copy.isna().sum()
# Out:
# Random          0
# Id              0
# Indication      0
# Diabetes        0
# IHD             0
# Hypertension    0
# Arrhythmia      0
# History         0
# IPSI            0
# Contra          0
# label           0
# dtype: int64

# %% [markdown]
# ### 2.2 Inspecting column Random

# %%
data_copy['Random'].value_counts(dropna=False)
# Out:
# 0.683506    4
# 0.506597    4
# 0.576184    4
# 0.899742    4
# 0.803415    3
#            ..
# 0.346396    1
# 0.801775    1
# 0.972183    1
# 0.692722    1
# 0.219026    1
# Name: Random, Length: 1212, dtype: int64

# %% [markdown]
# ### 2.3 Removing column Random

# %%
data_copy = data_copy.drop(columns=['Random'])

# %% [markdown]
# ### 2.4 Inspecting column Id
# #### This column should contain uniques. Checking for duplicates

# %%
duplicateIdDF = data_copy[data_copy.duplicated(['Id'])]

if duplicateIdDF.empty :
    print ("No Duplicates")
else:
    print (duplicateIdDF)
# Out:
# No Duplicates

# %% [markdown]
# #### Removing column Id
# No duplicates are present. Therefore it is assumed all data is unique. No further use for ID column and therefore dropping.

# %%
data_copy = data_copy.drop(columns=['Id'])

# %% [markdown]
# ### 2.5 Inspecting column Indication

# %%
data_copy['Indication'].value_counts(dropna=False)
# Out:
# A-F    489
# CVA    408
# TIA    388
# ASx    186
# Asx     32
# Name: Indication, dtype: int64

# %% [markdown]
# #### Setting all values to upper case
# As seen above, we are reading 5 different values for Indication when there should only be 4.
# This is due to two values being the same but having different capitialisation.
# Setting all values in our data to uppercase to solve this and avoid any further errors.

# %%
# Change all my string data to Uppercase to avoid any
data_copy['Indication'] = data_copy['Indication'].str.upper()
data_copy['Diabetes'] = data_copy['Diabetes'].str.upper() 
data_copy['IHD'] = data_copy['IHD'].str.upper() 
data_copy['Hypertension'] = data_copy['Hypertension'].str.upper() 
data_copy['Arrhythmia'] = data_copy['Arrhythmia'].str.upper() 
data_copy['History'] = data_copy['History'].str.upper() 
data_copy['label'] = data_copy['label'].str.upper() 

data_copy['Indication'].value_counts(dropna=False)
# Out:
# A-F    489
# CVA    408
# TIA    388
# ASX    218
# Name: Indication, dtype: int64

# %%
# Displays count Indication graph

#sb.countplot(data = data_copy, x= "Indication")
#y = plt.ylabel("Amount of People")
#sb.catplot('label', col="Indication", data = data_copy,kind='count' , height = 2.5)

# %% [markdown]
# #### One Hot Encoding - Indication
# Using One Hot Encoding to split Indication into 4 boolean columns to prevent the data being misinterpreted later on in other algorithms.
# https://pbpython.com/categorical-encoding.html

# %%
data_copy = pd.get_dummies(data_copy, columns=["Indication"])
data_copy.head()
# Out:
#   Diabetes  IHD Hypertension Arrhythmia History  IPSI Contra   label  \
# 0       NO   NO          YES         NO      NO  78.0    20   NORISK
# 1       NO   NO           NO         NO      NO  70.0    60   NORISK
# 2       NO  YES          YES         NO      NO  95.0     40    RISK
# 3       NO   NO          YES         NO      NO  90.0     85    RISK
# 4       NO   NO           NO         NO      NO  70.0    20   NORISK
#
#    Indication_A-F  Indication_ASX  Indication_CVA  Indication_TIA
# 0               1               0               0               0
# 1               0               0               0               1
# 2               1               0               0               0
# 3               0               0               0               1
# 4               0               0               1               0

# %% [markdown]
# ### 2.6 Inspecting each binary column.

# %%
data_copy['Diabetes'].value_counts(dropna=False)
# Out:
# NO     1428
# YES      75
# Name: Diabetes, dtype: int64

# %%
data_copy['IHD'].value_counts(dropna=False)
# Out:
# NO     791
# YES    712
# Name: IHD, dtype: int64

# %%
data_copy['Hypertension'].value_counts(dropna=False)
# Out:
# NO     777
# YES    726
# Name: Hypertension, dtype: int64

# %%
data_copy['Arrhythmia'].value_counts(dropna=False)
# Out:
# NO     1179
# YES     324
# Name: Arrhythmia, dtype: int64

# %%
data_copy['History'].value_counts(dropna=False)
# Out:
# NO     1481
# YES      22
# Name: History, dtype: int64

# %% [markdown]
# #### Changing each binary column to display True for YES and False for NO.
# Setting these values to true and false will make them readable to algorithms and models later on

# %%
# Creating a map to change YES and NO to True and False respectively
yesToTrue = {'YES': True,'NO': False}

# Creating new columns in our data, Displaying True or False instead
data_copy = data_copy.assign(Diabetes_bool = data_copy['Diabetes'].map(yesToTrue),
                      IHD_bool = data_copy['IHD'].map(yesToTrue),
                      Hypertension_bool = data_copy['Hypertension'].map(yesToTrue),
                      Arrhythmia_bool = data_copy['Arrhythmia'].map(yesToTrue),
                      History_bool = data_copy['History'].map(yesToTrue))

# Now dropping the old columns which displayed YES or NO
data_copy = data_copy.drop(columns=['Diabetes','IHD','Hypertension','Arrhythmia','History'])

data_copy.head()
# Out:
#    IPSI Contra   label  Indication_A-F  Indication_ASX  Indication_CVA  \
# 0  78.0    20   NORISK               1               0               0
# 1  70.0    60   NORISK               0               0               0
# 2  95.0     40    RISK               1               0               0
# 3  90.0     85    RISK               0               0               0
# 4  70.0    20   NORISK               0               0               1
#
#    Indication_TIA  Diabetes_bool  IHD_bool  Hypertension_bool  \
# 0               0          False     False               True
# 1               1          False     False              False
# 2               0          False      True               True
# 3               1          False     False               True
# 4               0          False     False              False
#
#    Arrhythmia_bool  History_bool
# 0            False         False
# 1            False         False
# 2            False         False
# 3            False         False
# 4            False         False

# %% [markdown]
# ### 2.7 Inspecting column IPSI

# %%
data_copy['IPSI'].value_counts(dropna=False)
# Out:
# 70.0    230
# 75.0    221
# 80.0    185
# 90.0    173
# 95.0    155
# 73.0     83
# 85.0     76
# 76.0     74
# 78.0     49
# 68.0     32
# 99.0     30
# 60.0     29
# 81.0     28
# 82.0     25
# 50.0     23
# 65.0     14
# 71.0     13
# 79.0     13
# 77.0      9
# 55.0      9
# 74.0      7
# 97.0      7
# 51.0      7
# 69.0      3
# 84.0      2
# 72.0      2
# 67.0      2
# 98.0      1
# 35.0      1
# Name: IPSI, dtype: int64

# %% [markdown]
# ### 2.8 Inspecting column Contra

# %%
data_copy['Contra'].value_counts(dropna=False)
# Out:
# 100     238
# 20      191
# 30      150
# 50      131
# 40      101
# 60       93
# 50       51
# 10       49
# 100      39
# 70       34
# 90       34
# 95       32
# 75       31
# 25       30
# 80       29
# 75       29
# 80       24
# 85       24
# 35       22
# 70       18
# 15       18
# 55       14
# 65       13
# 30       12
# 85       11
# 51       11
# 90       10
# 55        9
# 53        9
# 40        7
# 73        7
# 45        6
# 60        6
# 35        5
# 16        4
# 65        4
# 62        3
# 79        2
#           1
# 10        1
# Name: Contra, dtype: int64

# %% [markdown]
# #### Compare column Contra to IPSI
# An empty value is present in Contra.
# Will compare to IPSI to see if any coorelation is present.

# %%
colour = data_copy.label.map({'RISK':'b','NORISK':'r', 'UNKNOWN':'g', 'NAN':'y' })
ax1 = plt.scatter(data_copy['Contra'], data_copy['IPSI'],c= colour)
ax1.axes.set_ylabel('IPSI')
ax1.axes.set_xlabel('Contra')
# Out:
# Text(0.5, 0, 'Contra')

# %% [markdown]
# #### Turning empty value in Contra to NaN
# No correlation was found between Contra and IPSI alone. Therefore changing the value to NaN and will drop later.

# %%
data_copy=data_copy.replace(r'^\s*$', np.nan, regex=True)
data_copy.dropna(inplace=True)

# %% [markdown]
# #### Changing type of Contra to int

# %%
data_copy['Contra'] = data_copy['Contra'].str.strip('Contra').astype('int64')

# %% [markdown]
# ### 2.9 Inspect column label

# %%
data_copy['label'].value_counts(dropna=False)
# Out:
# NORISK     1000
# RISK        500
# UNKNOWN       2
# Name: label, dtype: int64

# %% [markdown]
# #### Removing records contain UNKNOWN
# Column lable contains two UNKNOWN values.
# Changing these to NaN and dropping

# %%
data_copy['label'] = data_copy['label'].replace("UNKNOWN", np.nan)
data_copy.dropna(inplace=True)

# %%
# Creating a map to change YES and NO to True and False respectively
riskToTrue = {'RISK': 1,'NORISK': 0}

data_copy = data_copy.assign(label_bool = data_copy['label'].map(riskToTrue))
data_copy = data_copy.drop(columns=['label'])
data_copy.head()
# Out:
#    IPSI  Contra  Indication_A-F  Indication_ASX  Indication_CVA  \
# 0  78.0      20               1               0               0
# 1  70.0      60               0               0               0
# 2  95.0      40               1               0               0
# 3  90.0      85               0               0               0
# 4  70.0      20               0               0               1
#
#    Indication_TIA  Diabetes_bool  IHD_bool  Hypertension_bool  \
# 0               0          False     False               True
# 1               1          False     False              False
# 2               0          False      True               True
# 3               1          False     False               True
# 4               0          False     False              False
#
#    Arrhythmia_bool  History_bool  label_bool
# 0            False         False           0
# 1            False         False           0
# 2            False         False           1
# 3            False         False           1
# 4            False         False           0

# %% [markdown]
# # 3.0 Data Models
# Will be creating multiple models to analyse the data.
# These models will be using a 70%-30% split of training and test data respectively.
#
# ## 3.1 Defining Test and Training Data
# ### Define X & Y.
# X being our cleaned and filtered data without the label column.
# Y being our label values.

# %%
# Define our x and y values for our training model
# X contains all columns except label
X = data_copy.drop(columns=['label_bool'])

# Y contains label values.
Y = data_copy['label_bool'].values

# %% [markdown]
# ### Create train test split
# Once we have our X and Y, we can split our data into 30% test data and 70% training data

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, shuffle=True)

# %% [markdown]
# ## 3.2 Nearest Neighbour Model (KNN)
# https://towardsdatascience.com/building-a-k-nearest-neighbors-k-nn-model-with-scikit-learn-51209555453a
# https://towardsdatascience.com/knn-using-scikit-learn-c6bed765be75
# https://www.quora.com/How-can-I-choose-the-best-K-in-KNN-K-nearest-neighbour-classification
# KNN model requires a value K. K determines how many neighbours are used to decide a given value.
#
# To find the best value for K, we will create multiple KNN models with different K values and inspect each of their accuracies.

# %% [markdown]
# ### 3.2.1 Finding a value for K - Using Predictor

# %%
k_range = range(1,50)
knn_scores = {}
knn_scores_list = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k, metric ='euclidean')
    knn.fit(xTrain,yTrain)
    yPred = knn.predict(xTest)
    knn_scores[k] = metrics.accuracy_score(yTest,yPred)
    knn_scores_list.append(metrics.accuracy_score(yTest,yPred))

# %%
plt.plot(k_range,knn_scores_list)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
print(knn_scores_list)
## 0.98, 0.9822, 0.991, 0.984
# Out:
# [0.9822222222222222, 0.9666666666666667, 0.9577777777777777, 0.9288888888888889, 0.9155555555555556, 0.9155555555555556, 0.9133333333333333, 0.9088888888888889, 0.9, 0.9022222222222223, 0.9022222222222223, 0.9044444444444445, 0.8933333333333333, 0.9044444444444445, 0.9088888888888889, 0.9044444444444445, 0.9066666666666666, 0.8955555555555555, 0.9044444444444445, 0.8933333333333333, 0.8955555555555555, 0.8866666666666667, 0.8777777777777778, 0.8822222222222222, 0.8822222222222222, 0.88, 0.8822222222222222, 0.88, 0.88, 0.88, 0.88, 0.88, 0.8822222222222222, 0.8777777777777778, 0.88, 0.88, 0.88, 0.8777777777777778, 0.8822222222222222, 0.88, 0.88, 0.88, 0.8755555555555555, 0.8755555555555555, 0.8733333333333333, 0.8622222222222222, 0.8577777777777778, 0.8577777777777778, 0.8622222222222222]

# %% [markdown]
# ### 3.2.3 Finding a value for K - Square root n
# n being the number of data points

# %%
print (math.sqrt(len(yTrain)))
# Out:
# 32.4037034920393

# %% [markdown]
# ### 3.2.4 Implementing K into KNN model
# Setting k to 31.

# %%
# Create our KNN classifier. Setting K to 31
knn = KNeighborsClassifier(n_neighbors = 31)
 
# Fit our trained data in the classifer
knn.fit (xTrain, yTrain)

# Create our predictor
yPred = knn.predict(xTest)

# %% [markdown]
# ### 3.2.5 Accuracy of KNN Model

# %%
# Check accuracy of our model
print("Accuracy:",metrics.accuracy_score(yTest, yPred))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, yPred))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,yPred))
# Out:
# Accuracy: 0.88
# Mean Absolute Error: 0.12
# Mean Squared Error: 0.12

# %%
print(metrics.classification_report(yTest,yPred))
print("KNN Model with K set to 31")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       307
#            1       0.82      0.79      0.81       143
#
#     accuracy                           0.88       450
#    macro avg       0.86      0.86      0.86       450
# weighted avg       0.88      0.88      0.88       450
#
# KNN Model with K set to 31

# %% [markdown]
# ### 3.2.6 Implementing KNN model with k-Fold Cross Validation

# %%
knn = KNeighborsClassifier(n_neighbors=31, metric ='euclidean')

cv_scores = cross_val_score(knn, X, Y, cv=5)
print(np.mean(cv_scores))
# Out:
# 0.8766666666666666

# %% [markdown]
# ## 3.3 Decision Tree Model
# https://towardsdatascience.com/scikit-learn-decision-trees-explained-803f3812290d
# https://towardsdatascience.com/decision-tree-classification-de64fc4d5aac

# %% [markdown]
# ### 3.3.1 Implementing Decision Tree Model

# %%
clf = tree.DecisionTreeClassifier(max_depth = 5)
clf = clf.fit(xTrain, yTrain)
plt.rcParams["figure.figsize"] = (20,20)
tree.plot_tree(clf)
# Out:
# [Text(590.1923076923076, 978.48, 'X[9] <= 0.5\ngini = 0.449\nsamples = 1050\nvalue = [693, 357]'),
#  Text(343.38461538461536, 761.0400000000001, 'X[1] <= 61.0\ngini = 0.271\nsamples = 817\nvalue = [685, 132]'),
#  Text(171.69230769230768, 543.6, 'X[6] <= 0.5\ngini = 0.067\nsamples = 572\nvalue = [552, 20]'),
#  Text(85.84615384615384, 326.1600000000001, 'X[0] <= 87.5\ngini = 0.055\nsamples = 566\nvalue = [550, 16]'),
#  Text(42.92307692307692, 108.72000000000003, 'gini = 0.019\nsamples = 509\nvalue = [504, 5]'),
#  Text(128.76923076923077, 108.72000000000003, 'gini = 0.311\nsamples = 57\nvalue = [46, 11]'),
#  Text(257.53846153846155, 326.1600000000001, 'X[4] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(214.61538461538458, 108.72000000000003, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(300.46153846153845, 108.72000000000003, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(515.0769230769231, 543.6, 'X[8] <= 0.5\ngini = 0.496\nsamples = 245\nvalue = [133, 112]'),
#  Text(429.23076923076917, 326.1600000000001, 'X[0] <= 87.5\ngini = 0.328\nsamples = 140\nvalue = [111, 29]'),
#  Text(386.30769230769226, 108.72000000000003, 'gini = 0.145\nsamples = 114\nvalue = [105, 9]'),
#  Text(472.15384615384613, 108.72000000000003, 'gini = 0.355\nsamples = 26\nvalue = [6, 20]'),
#  Text(600.9230769230769, 326.1600000000001, 'X[0] <= 67.5\ngini = 0.331\nsamples = 105\nvalue = [22, 83]'),
#  Text(558.0, 108.72000000000003, 'gini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(643.8461538461538, 108.72000000000003, 'gini = 0.164\nsamples = 89\nvalue = [8, 81]'),
#  Text(836.9999999999999, 761.0400000000001, 'X[1] <= 42.5\ngini = 0.066\nsamples = 233\nvalue = [8, 225]'),
#  Text(729.6923076923076, 543.6, 'X[2] <= 0.5\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(686.7692307692307, 326.1600000000001, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(772.6153846153845, 326.1600000000001, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(944.3076923076923, 543.6, 'X[5] <= 0.5\ngini = 0.018\nsamples = 223\nvalue = [2, 221]'),
#  Text(858.4615384615383, 326.1600000000001, 'X[0] <= 72.5\ngini = 0.009\nsamples = 216\nvalue = [1, 215]'),
#  Text(815.5384615384614, 108.72000000000003, 'gini = 0.091\nsamples = 21\nvalue = [1, 20]'),
#  Text(901.3846153846154, 108.72000000000003, 'gini = 0.0\nsamples = 195\nvalue = [0, 195]'),
#  Text(1030.1538461538462, 326.1600000000001, 'X[7] <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(987.2307692307692, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1073.076923076923, 108.72000000000003, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]')]

# %% [markdown]
# ### 3.3.2 Accuracy of Decision Tree Model

# %%
yPred = clf.predict(xTest)
print("Accuracy:",metrics.accuracy_score(yTest, yPred))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, yPred))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,yPred))
print("Decision Tree Model")
# Out:
# Accuracy: 0.9288888888888889
# Mean Absolute Error: 0.07111111111111111
# Mean Squared Error: 0.07111111111111111
# Decision Tree Model

# %%
plt.rcParams["figure.figsize"] = (10,10)
skplt.metrics.plot_confusion_matrix(y_true= yTest, y_pred = yPred)

# %% [markdown]
# ## 3.4 Multi-Layer Perceptron

# %% [markdown]
# ### 3.4.1 Implementing Multi-Layer Perceptron

# %%
model = MLPClassifier(solver='sgd',activation='logistic',max_iter=5000, hidden_layer_sizes=(13))
trained_model = model.fit(xTrain,yTrain)
model_prediction = trained_model.predict(xTest)

# %%
skplt.metrics.plot_confusion_matrix(y_true = yTest, y_pred = model_prediction)

# %% [markdown]
# ### 3.4.2 Accuracy of Multi-Layer Perceptron

# %%
metrics.accuracy_score(yTest,model_prediction)
print("Accuracy:",metrics.accuracy_score(yTest, model_prediction))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, model_prediction))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,model_prediction))
print("Decision Tree Model")
# Out:
# Accuracy: 0.9044444444444445
# Mean Absolute Error: 0.09555555555555556
# Mean Squared Error: 0.09555555555555556
# Decision Tree Model

# %% [markdown]
# # 4.0 Reinspection of data

# %% [markdown]
# ### 4.1 Heatmap of our variables

# %%
sb.heatmap(data_copy.corr(),annot=True,fmt = '.2g')

# %% [markdown]
# The heatmap above suggests that compared to 'label_bool', the Indication values and History have little to no coorelation.

# %%
data_copy=data_copy.drop(columns=['History_bool','Indication_A-F','Indication_ASX','Indication_CVA','Indication_TIA'])
data_copy.head()
# Out:
#    IPSI  Contra  Diabetes_bool  IHD_bool  Hypertension_bool  Arrhythmia_bool  \
# 0  78.0      20          False     False               True            False
# 1  70.0      60          False     False              False            False
# 2  95.0      40          False      True               True            False
# 3  90.0      85          False     False               True            False
# 4  70.0      20          False     False              False            False
#
#    label_bool
# 0           0
# 1           0
# 2           1
# 3           1
# 4           0

# %% [markdown]
# # 5.0 Re-Run Models with new Data

# %% [markdown]
# ### Defining X & Y

# %%
# X contains all columns except label
X = data_copy.drop(columns=['label_bool'])

# Y contains label values.
Y = data_copy['label_bool'].values

# %% [markdown]
# ### Create train test split

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, shuffle=True)

# %% [markdown]
# ## KNN Model

# %%
# Create our KNN classifier. Setting K to 31
knn = KNeighborsClassifier(n_neighbors = 31)
 
# Fit our trained data in the classifer
knn.fit (xTrain, yTrain)

# Check accuracy of our model 
knn.score(xTest, yTest)
# Out:
# 0.8622222222222222

# %%
print(metrics.classification_report(yTest,yPred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.69       298
#            1       0.36      0.30      0.33       152
#
#     accuracy                           0.58       450
#    macro avg       0.51      0.51      0.51       450
# weighted avg       0.56      0.58      0.57       450

# %% [markdown]
# ## Decision Tree Model

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(xTrain, yTrain)
plt.rcParams["figure.figsize"] = (20,20)
tree.plot_tree(clf)
# Out:
# [Text(726.6105371900827, 1045.3846153846155, 'X[5] <= 0.5\ngini = 0.443\nsamples = 1050\nvalue = [702, 348]'),
#  Text(475.5681818181818, 961.7538461538462, 'X[1] <= 74.0\ngini = 0.255\nsamples = 815\nvalue = [693, 122]'),
#  Text(280.1528925619835, 878.123076923077, 'X[0] <= 87.5\ngini = 0.095\nsamples = 640\nvalue = [608, 32]'),
#  Text(182.15702479338844, 794.4923076923078, 'X[2] <= 0.5\ngini = 0.037\nsamples = 578\nvalue = [567, 11]'),
#  Text(115.28925619834712, 710.8615384615384, 'X[4] <= 0.5\ngini = 0.031\nsamples = 573\nvalue = [564, 9]'),
#  Text(36.892561983471076, 627.2307692307693, 'X[0] <= 79.5\ngini = 0.006\nsamples = 342\nvalue = [341, 1]'),
#  Text(18.446280991735538, 543.6, 'gini = 0.0\nsamples = 282\nvalue = [282, 0]'),
#  Text(55.33884297520662, 543.6, 'X[1] <= 45.0\ngini = 0.033\nsamples = 60\nvalue = [59, 1]'),
#  Text(36.892561983471076, 459.96923076923076, 'gini = 0.0\nsamples = 37\nvalue = [37, 0]'),
#  Text(73.78512396694215, 459.96923076923076, 'X[0] <= 80.5\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(55.33884297520662, 376.3384615384616, 'X[1] <= 50.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(36.892561983471076, 292.70769230769235, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(73.78512396694215, 292.70769230769235, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(92.23140495867769, 376.3384615384616, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(193.68595041322314, 627.2307692307693, 'X[1] <= 61.0\ngini = 0.067\nsamples = 231\nvalue = [223, 8]'),
#  Text(156.79338842975207, 543.6, 'X[3] <= 0.5\ngini = 0.044\nsamples = 223\nvalue = [218, 5]'),
#  Text(138.34710743801654, 459.96923076923076, 'gini = 0.0\nsamples = 136\nvalue = [136, 0]'),
#  Text(175.2396694214876, 459.96923076923076, 'X[1] <= 25.0\ngini = 0.108\nsamples = 87\nvalue = [82, 5]'),
#  Text(156.79338842975207, 376.3384615384616, 'gini = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(193.68595041322314, 376.3384615384616, 'X[1] <= 45.0\ngini = 0.183\nsamples = 49\nvalue = [44, 5]'),
#  Text(110.67768595041323, 292.70769230769235, 'X[0] <= 75.5\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(73.78512396694215, 209.0769230769231, 'X[0] <= 72.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(55.33884297520662, 125.44615384615383, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(92.23140495867769, 125.44615384615383, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(147.5702479338843, 209.0769230769231, 'X[1] <= 35.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(129.12396694214877, 125.44615384615383, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(166.01652892561984, 125.44615384615383, 'X[0] <= 78.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(147.5702479338843, 41.81538461538457, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(184.46280991735537, 41.81538461538457, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(276.6942148760331, 292.70769230769235, 'X[1] <= 55.0\ngini = 0.108\nsamples = 35\nvalue = [33, 2]'),
#  Text(258.24793388429754, 209.0769230769231, 'X[0] <= 80.5\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(239.801652892562, 125.44615384615383, 'X[0] <= 75.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(221.35537190082647, 41.81538461538457, 'gini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(258.24793388429754, 41.81538461538457, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(276.6942148760331, 125.44615384615383, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(295.1404958677686, 209.0769230769231, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(230.57851239669424, 543.6, 'X[1] <= 67.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(212.13223140495867, 459.96923076923076, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(249.02479338842977, 459.96923076923076, 'X[3] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(230.57851239669424, 376.3384615384616, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(267.4710743801653, 376.3384615384616, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(249.02479338842977, 710.8615384615384, 'X[1] <= 35.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(230.57851239669424, 627.2307692307693, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(267.4710743801653, 627.2307692307693, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(378.1487603305785, 794.4923076923078, 'X[4] <= 0.5\ngini = 0.448\nsamples = 62\nvalue = [41, 21]'),
#  Text(322.8099173553719, 710.8615384615384, 'X[3] <= 0.5\ngini = 0.093\nsamples = 41\nvalue = [39, 2]'),
#  Text(304.3636363636364, 627.2307692307693, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(341.25619834710744, 627.2307692307693, 'X[0] <= 94.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(322.8099173553719, 543.6, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(359.702479338843, 543.6, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(433.4876033057851, 710.8615384615384, 'X[3] <= 0.5\ngini = 0.172\nsamples = 21\nvalue = [2, 19]'),
#  Text(415.0413223140496, 627.2307692307693, 'X[0] <= 93.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(396.59504132231405, 543.6, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(433.4876033057851, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(451.9338842975207, 627.2307692307693, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(670.9834710743802, 878.123076923077, 'X[4] <= 0.5\ngini = 0.5\nsamples = 175\nvalue = [85, 90]'),
#  Text(562.6115702479339, 794.4923076923078, 'X[1] <= 87.5\ngini = 0.417\nsamples = 98\nvalue = [69, 29]'),
#  Text(544.1652892561983, 710.8615384615384, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(581.0578512396694, 710.8615384615384, 'X[0] <= 77.5\ngini = 0.497\nsamples = 54\nvalue = [25, 29]'),
#  Text(507.2727272727273, 627.2307692307693, 'X[3] <= 0.5\ngini = 0.269\nsamples = 25\nvalue = [21, 4]'),
#  Text(470.38016528925624, 543.6, 'X[0] <= 72.5\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(451.9338842975207, 459.96923076923076, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(488.8264462809918, 459.96923076923076, 'X[1] <= 95.0\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(470.38016528925624, 376.3384615384616, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(507.2727272727273, 376.3384615384616, 'gini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(544.1652892561983, 543.6, 'X[1] <= 95.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(525.7190082644628, 459.96923076923076, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(562.6115702479339, 459.96923076923076, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(654.8429752066116, 627.2307692307693, 'X[1] <= 92.5\ngini = 0.238\nsamples = 29\nvalue = [4, 25]'),
#  Text(617.9504132231406, 543.6, 'X[3] <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(599.504132231405, 459.96923076923076, 'X[0] <= 85.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(581.0578512396694, 376.3384615384616, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(617.9504132231406, 376.3384615384616, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(636.3966942148761, 459.96923076923076, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(691.7355371900827, 543.6, 'X[0] <= 82.5\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(673.2892561983472, 459.96923076923076, 'X[3] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(654.8429752066116, 376.3384615384616, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(691.7355371900827, 376.3384615384616, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(710.1818181818182, 459.96923076923076, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(779.3553719008265, 794.4923076923078, 'X[0] <= 65.0\ngini = 0.329\nsamples = 77\nvalue = [16, 61]'),
#  Text(728.6280991735538, 710.8615384615384, 'X[2] <= 0.5\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(710.1818181818182, 627.2307692307693, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(747.0743801652893, 627.2307692307693, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(830.0826446280992, 710.8615384615384, 'X[1] <= 77.0\ngini = 0.148\nsamples = 62\nvalue = [5, 57]'),
#  Text(783.9669421487604, 627.2307692307693, 'X[3] <= 0.5\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(765.5206611570248, 543.6, 'X[2] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(747.0743801652893, 459.96923076923076, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(783.9669421487604, 459.96923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(802.4132231404959, 543.6, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(876.198347107438, 627.2307692307693, 'X[0] <= 82.5\ngini = 0.078\nsamples = 49\nvalue = [2, 47]'),
#  Text(857.7520661157025, 543.6, 'X[1] <= 90.0\ngini = 0.147\nsamples = 25\nvalue = [2, 23]'),
#  Text(820.8595041322315, 459.96923076923076, 'X[2] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(802.4132231404959, 376.3384615384616, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(839.305785123967, 376.3384615384616, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(894.6446280991736, 459.96923076923076, 'X[3] <= 0.5\ngini = 0.087\nsamples = 22\nvalue = [1, 21]'),
#  Text(876.198347107438, 376.3384615384616, 'X[0] <= 72.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(857.7520661157025, 292.70769230769235, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(894.6446280991736, 292.70769230769235, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(913.0909090909091, 376.3384615384616, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(894.6446280991736, 543.6, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(977.6528925619835, 961.7538461538462, 'X[1] <= 42.5\ngini = 0.074\nsamples = 235\nvalue = [9, 226]'),
#  Text(894.6446280991736, 878.123076923077, 'X[0] <= 78.0\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(876.198347107438, 794.4923076923078, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(913.0909090909091, 794.4923076923078, 'X[0] <= 85.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(894.6446280991736, 710.8615384615384, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(931.5371900826447, 710.8615384615384, 'X[3] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(913.0909090909091, 627.2307692307693, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(949.9834710743802, 627.2307692307693, 'gini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(1060.6611570247935, 878.123076923077, 'X[0] <= 82.5\ngini = 0.018\nsamples = 221\nvalue = [2, 219]'),
#  Text(1042.2148760330579, 794.4923076923078, 'X[4] <= 0.5\ngini = 0.048\nsamples = 82\nvalue = [2, 80]'),
#  Text(1005.3223140495868, 710.8615384615384, 'X[1] <= 87.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(986.8760330578513, 627.2307692307693, 'X[1] <= 67.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(968.4297520661157, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1005.3223140495868, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1023.7685950413223, 627.2307692307693, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(1079.107438016529, 710.8615384615384, 'X[3] <= 0.5\ngini = 0.026\nsamples = 75\nvalue = [1, 74]'),
#  Text(1060.6611570247935, 627.2307692307693, 'X[0] <= 79.5\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(1042.2148760330579, 543.6, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(1079.107438016529, 543.6, 'X[1] <= 90.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(1060.6611570247935, 459.96923076923076, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(1097.5537190082646, 459.96923076923076, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(1097.5537190082646, 627.2307692307693, 'gini = 0.0\nsamples = 56\nvalue = [0, 56]'),
#  Text(1079.107438016529, 794.4923076923078, 'gini = 0.0\nsamples = 139\nvalue = [0, 139]')]

# %%
yPred = clf.predict(xTest)
print("Accuracy:",metrics.accuracy_score(yTest, yPred))
print("Mean Absolute Error:", metrics.mean_absolute_error(yTest, yPred))
print("Mean Squared Error:", metrics.mean_squared_error(yTest,yPred))
# Out:
# Accuracy: 0.9844444444444445
# Mean Absolute Error: 0.015555555555555555
# Mean Squared Error: 0.015555555555555555

# %%
plt.rcParams["figure.figsize"] = (10,10)
skplt.metrics.plot_confusion_matrix(y_true= yTest, y_pred = yPred)

# %% [markdown]
# ## Multi-Layer Perceptron

# %%
model = MLPClassifier(solver='sgd',activation='logistic',max_iter=5000000, hidden_layer_sizes=(400))
trained_model = model.fit(xTrain,yTrain)
model_prediction = trained_model.predict(xTest)

skplt.metrics.plot_confusion_matrix(y_true = yTest, y_pred = model_prediction)

# %%
metrics.accuracy_score(yTest,model_prediction)
# Out:
# 0.8955555555555555
