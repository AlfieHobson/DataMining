# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import scikitplot as skplt
import sklearn 
from sklearn import datasets
from sklearn import tree
from sklearn.model_selection import cross_val_score

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %%
iris = datasets.load_iris()
class_names = iris.target_names
x = iris.data
y = iris.target

# %%
xTrain, xTest, yTrain, yTest = sklearn.model_selection.train_test_split(x, y,test_size=0.3, shuffle=True)
clf = tree.DecisionTreeClassifier()
clf = clf.fit(xTrain, yTrain)
tree.plot_tree(clf, feature_names=iris.feature_names)
# Out:
# [Text(446.4, 978.48, 'petal length (cm) <= 2.45\ngini = 0.664\nsamples = 105\nvalue = [35, 39, 31]'),
#  Text(334.79999999999995, 761.0400000000001, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(558.0, 761.0400000000001, 'petal width (cm) <= 1.75\ngini = 0.493\nsamples = 70\nvalue = [0, 39, 31]'),
#  Text(223.2, 543.6, 'petal length (cm) <= 5.05\ngini = 0.095\nsamples = 40\nvalue = [0, 38, 2]'),
#  Text(111.6, 326.1600000000001, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(334.79999999999995, 326.1600000000001, 'sepal length (cm) <= 6.05\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(223.2, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(446.4, 108.72000000000003, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(892.8, 543.6, 'petal length (cm) <= 4.85\ngini = 0.064\nsamples = 30\nvalue = [0, 1, 29]'),
#  Text(781.1999999999999, 326.1600000000001, 'sepal length (cm) <= 5.95\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(669.5999999999999, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(892.8, 108.72000000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(1004.4, 326.1600000000001, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 28]')]

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(iris.data, iris.target)
plt.rcParams["figure.figsize"] = (20,20)
tree.plot_tree(clf, feature_names=iris.feature_names)
# Out:
# [Text(558.0, 996.6, 'petal length (cm) <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(472.15384615384613, 815.4000000000001, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(643.8461538461538, 815.4000000000001, 'petal width (cm) <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(343.38461538461536, 634.2, 'petal length (cm) <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(171.69230769230768, 453.0, 'petal width (cm) <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(85.84615384615384, 271.79999999999995, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(257.53846153846155, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(515.0769230769231, 453.0, 'petal width (cm) <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(429.23076923076917, 271.79999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(600.9230769230769, 271.79999999999995, 'petal length (cm) <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(515.0769230769231, 90.59999999999991, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(686.7692307692307, 90.59999999999991, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(944.3076923076923, 634.2, 'petal length (cm) <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(858.4615384615383, 453.0, 'sepal width (cm) <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(772.6153846153845, 271.79999999999995, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(944.3076923076923, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(1030.1538461538462, 453.0, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
clf = clf.fit(xTrain, yTrain)
yPred = clf.predict(xTest)
print (yPred)
print (yTest)
# Out:
# [1 1 2 0 1 2 2 0 1 2 0 0 2 2 1 2 2 0 0 0 1 0 0 2 2 0 2 0 1 2 1 0 0 1 2 1 1
#  2 1 0 2 1 2 2 0]
# [1 1 2 0 1 2 2 0 1 2 0 0 2 2 1 2 2 0 0 0 1 0 0 2 2 0 2 0 1 2 2 0 0 1 2 1 1
#  2 2 0 2 1 2 2 0]

# %%
sklearn.metrics.confusion_matrix(yTest,yPred)
# Out:
# array([[15,  0,  0],
#        [ 0, 11,  0],
#        [ 0,  2, 17]])

# %%
plt.rcParams["figure.figsize"] = (20,20)
skplt.metrics.plot_confusion_matrix(
    yTest,
    yPred,
    normalize=False,
    title='Confusion Matrix, without normalisation'
)
